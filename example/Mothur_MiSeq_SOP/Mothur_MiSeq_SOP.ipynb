# %%
import os
import sys

# # change working directory to allow import of package without installation
work_dir = os.getcwd()
print(os.getcwd())
base_dir = os.path.join(work_dir, '..', '..')
os.chdir(base_dir)
print(os.getcwd())

from rhea import Mothur
os.chdir(work_dir)

# # setup mothur object
mothur = Mothur()
mothur.parse_log_file = True
mothur.display_output = True
# Out:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP
# C:\Users\campen\Documents\coding\python\rhea

# %%
mothur.make.file(inputdir='.', type='fastq', prefix='stability')
# Out:
# mothur > make.file(inputdir=.,type=fastq,prefix=stability)
# Setting input directory to: C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.files
#
# [WARNING]: your sequence names contained ':'.  I changed them to '_' to avoid problems in your downstream analysis.
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# C:\Users\campen\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     670                 type_pprinters=self.type_printers,
#     671                 deferred_pprinters=self.deferred_printers)
# --> 672             printer.pretty(obj)
#     673             printer.flush()
#     674             return stream.getvalue()
#
# C:\Users\campen\Anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# C:\Users\campen\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _default_pprint(obj, p, cycle)
#     501     if _safe_getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     502         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 503         _repr_pprint(obj, p, cycle)
#     504         return
#     505     p.begin_group(1, '<')
#
# C:\Users\campen\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     699     """A pprint that just redirects to the normal repr function."""
#     700     # Find newlines and replace them with p.break_()
# --> 701     output = repr(obj)
#     702     for idx,output_line in enumerate(output.splitlines()):
#     703         if idx:
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# C:\Users\campen\Documents\coding\python\rhea\rhea\core.py in __repr__(self)
#      43     def __repr__(self):
#      44
# ---> 45         return '%s' % self
#      46
#      47
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
mothur.make.contigs(file='stability.2.files', processors=8)

# %%
mothur.summary.seqs()

# %%
mothur.screen.seqs(fasta='current', group='current', maxambig=0, maxlength=275)
