# %% [markdown]
# # Example: Mothur MiSeq SOP
#
# This example usage of rhea uses the Mothur MiSeq SOP.

# %% [markdown]
# This example requires the following packages to run (that are not a requirement of rhea itself):
#
# * wget
#
# These can be installed at the command line with `pip install <package_name>`.

# %%
import os
import sys

# change working directory to allow import of package without installation
work_dir = os.getcwd()
base_dir = os.path.join(work_dir, '..', '..')
os.chdir(base_dir)

from rhea import Mothur
os.chdir(work_dir)

# %% [markdown]
# The rhea package revolves around the central `Mothur` class. Before running any mothur commands we need to create an instance of the `Mothur` class that we will use to run our `mothur` commands. We can also set attributes on this `Mothur` class to apply different configuration options that affect the way that `mothur` will be executed, and how the output will be displayed.

# %%
# create Mothur class instance
mothur = Mothur()

# configure the mothur object
mothur.suppress_logfile = True
mothur.verbosity = 1

# %% [markdown]
# First we need to download all the files required for running this example.

# %%
import wget
from zipfile import ZipFile

# download and unpack example data
if not os.path.isdir('MiSeq_SOP'):  
    
    # onyl redownload data if neither the packed or unpacked forma already exist
    if not os.path.isfile('MiSeqSOPData.zip'):
        print('Downloading Example Data...')
        data_archive = wget.download('https://www.mothur.org/w/images/d/d6/MiSeqSOPData.zip')

    # unpack data
    print('\nExtracting example data...')
    data = ZipFile(data_archive)
    data.extractall()
    print('done!')
    
else:
    print('Example data already exists. Skipping download and extraction.')
# Out:
# Example data already exists. Skipping download and extraction.

# %%
# download and unpack SILVA reference alignment
if not os.path.isdir('silva.bacteria'):  
    
    # onyl redownload data if neither the packed or unpacked forma already exist
    if not os.path.isfile('Silva.bacteria.zip'):
        print('Downloading SILVA referece alignment...')
        data_archive = wget.download('https://www.mothur.org/w/images/9/98/Silva.bacteria.zip')

    # unpack data
    print('\nExtracting SILVA reference alignment...')
    data = ZipFile(data_archive)
    data.extractall()
    print('done!')
    
else:
    print('SILVA reference alignment already exists. Skipping download and extraction.')
# Out:
# SILVA reference alignment already exists. Skipping download and extraction.

# %%
# download and unpack SILVA reference alignment
if not os.path.isfile('trainset9_032012.pds.fasta') or not os.path.isfile('trainset9_032012.pds.tax'):  
    
    # onyl redownload data if neither the packed or unpacked forma already exist
    if not os.path.isfile('Trainset9_032012.pds.zip'):
        print('Downloading RDP training set...')
        data_archive = wget.download('https://www.mothur.org/w/images/5/59/Trainset9_032012.pds.zip')
        
    # unpack data
    print('\nExtracting RDP training set...')
    data = ZipFile(data_archive)
    data.extractall()
    print('done!')
    
else:
    print('RDP training set already exists. Skipping download and extraction.')
# Out:
# RDP training set already exists. Skipping download and extraction.

# %%
## Not doing this right now as make.contigs is broken, using the one provided in the example data instead
# mothur.make.file(inputdir='MiSeq_SOP', type='fastq', prefix='stability')

# %%
# we're setting up the input and output directories explicitly to prevent anything weird
mothur = mothur.set.dir(input='MiSeq_SOP', output='.')
mothur = mothur.make.contigs(file='stability.files')

# resetting the input directory after reading in the sequencing files from the sub-folder
mothur = mothur.set.dir(input=mothur.current_dirs['output'])
# Out:
# mothur > set.dir(input=MiSeq_SOP,output=.)
# Mothur's directories:
# outputDir=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\
# inputDir=MiSeq_SOP\
#
# mothur > make.contigs(file=stability.files)
#
# Using 1 processors.
#
# >>>>>	Processing file pair MiSeq_SOP\F3D0_S188_L001_R1_001.fastq - MiSeq_SOP\F3D0_S188_L001_R2_001.fastq (files 1 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 7793
# Done.
#
# It took 5 secs to assemble 7793 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D141_S207_L001_R1_001.fastq - MiSeq_SOP\F3D141_S207_L001_R2_001.fastq (files 2 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 5958
# Done.
#
# It took 4 secs to assemble 5958 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D142_S208_L001_R1_001.fastq - MiSeq_SOP\F3D142_S208_L001_R2_001.fastq (files 3 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 3183
# Done.
#
# It took 2 secs to assemble 3183 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D143_S209_L001_R1_001.fastq - MiSeq_SOP\F3D143_S209_L001_R2_001.fastq (files 4 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 3178
# Done.
#
# It took 3 secs to assemble 3178 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D144_S210_L001_R1_001.fastq - MiSeq_SOP\F3D144_S210_L001_R2_001.fastq (files 5 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 4827
# Done.
#
# It took 3 secs to assemble 4827 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D145_S211_L001_R1_001.fastq - MiSeq_SOP\F3D145_S211_L001_R2_001.fastq (files 6 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 7377
# Done.
#
# It took 5 secs to assemble 7377 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D146_S212_L001_R1_001.fastq - MiSeq_SOP\F3D146_S212_L001_R2_001.fastq (files 7 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 5021
# Done.
#
# It took 4 secs to assemble 5021 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D147_S213_L001_R1_001.fastq - MiSeq_SOP\F3D147_S213_L001_R2_001.fastq (files 8 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 17070
# Done.
#
# It took 11 secs to assemble 17070 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D148_S214_L001_R1_001.fastq - MiSeq_SOP\F3D148_S214_L001_R2_001.fastq (files 9 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 12405
# Done.
#
# It took 9 secs to assemble 12405 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D149_S215_L001_R1_001.fastq - MiSeq_SOP\F3D149_S215_L001_R2_001.fastq (files 10 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 13083
# Done.
#
# It took 9 secs to assemble 13083 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D150_S216_L001_R1_001.fastq - MiSeq_SOP\F3D150_S216_L001_R2_001.fastq (files 11 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 5509
# Done.
#
# It took 4 secs to assemble 5509 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D1_S189_L001_R1_001.fastq - MiSeq_SOP\F3D1_S189_L001_R2_001.fastq (files 12 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 5869
# Done.
#
# It took 4 secs to assemble 5869 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D2_S190_L001_R1_001.fastq - MiSeq_SOP\F3D2_S190_L001_R2_001.fastq (files 13 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 19620
# Done.
#
# It took 13 secs to assemble 19620 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D3_S191_L001_R1_001.fastq - MiSeq_SOP\F3D3_S191_L001_R2_001.fastq (files 14 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 6758
# Done.
#
# It took 5 secs to assemble 6758 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D5_S193_L001_R1_001.fastq - MiSeq_SOP\F3D5_S193_L001_R2_001.fastq (files 15 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 4448
# Done.
#
# It took 3 secs to assemble 4448 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D6_S194_L001_R1_001.fastq - MiSeq_SOP\F3D6_S194_L001_R2_001.fastq (files 16 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 7989
# Done.
#
# It took 5 secs to assemble 7989 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D7_S195_L001_R1_001.fastq - MiSeq_SOP\F3D7_S195_L001_R2_001.fastq (files 17 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 5129
# Done.
#
# It took 4 secs to assemble 5129 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D8_S196_L001_R1_001.fastq - MiSeq_SOP\F3D8_S196_L001_R2_001.fastq (files 18 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 5294
# Done.
#
# It took 3 secs to assemble 5294 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\F3D9_S197_L001_R1_001.fastq - MiSeq_SOP\F3D9_S197_L001_R2_001.fastq (files 19 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 7070
# Done.
#
# It took 5 secs to assemble 7070 reads.
#
#
# >>>>>	Processing file pair MiSeq_SOP\Mock_S280_L001_R1_001.fastq - MiSeq_SOP\Mock_S280_L001_R2_001.fastq (files 20 of 20)	<<<<<
# Making contigs...
# 1000
# 2000
# 3000
# 4000
# 4779
# Done.
#
# It took 4 secs to assemble 4779 reads.
#
# It took 105 secs to process 152360 sequences.
#
# Group count:
# F3D0	7793
# F3D1	5869
# F3D141	5958
# F3D142	3183
# F3D143	3178
# F3D144	4827
# F3D145	7377
# F3D146	5021
# F3D147	17070
# F3D148	12405
# F3D149	13083
# F3D150	5509
# F3D2	19620
# F3D3	6758
# F3D5	4448
# F3D6	7989
# F3D7	5129
# F3D8	5294
# F3D9	7070
# Mock	4779
#
# Total of all groups is 152360
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.fasta
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.qual
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.contigs.report
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.scrap.contigs.fasta
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.scrap.contigs.qual
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.contigs.groups
#
# [WARNING]: your sequence names contained ':'.  I changed them to '_' to avoid problems in your downstream analysis.
#
# mothur > get.current()
#
# Current RAM usage: 6.95547 Gigabytes. Total Ram: 63.8537 Gigabytes.
#
# Current files saved by mothur:
# fasta=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.fasta
# group=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.contigs.groups
# qfile=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.qual
# contigsreport=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.contigs.report
#
# Current input directory saved by mothur: MiSeq_SOP\
#
# Current output directory saved by mothur: C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\
#
# Current default directory saved by mothur: C:\Users\campen\mothur\1.39.5\mothur\mothur\
#
# Current working directory: C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\current_files.summary
#
#
# mothur > quit()
#
#
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Detected 1 [WARNING] messages, please review.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# mothur > set.dir(input=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\)
# Mothur's directories:
# inputDir=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\

# %%
mothur = mothur.summary.seqs()
# Out:
# mothur > summary.seqs()
# Using C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.fasta as input file for the fasta parameter.
#
# Using 1 processors.
#
# 		Start	End	NBases	Ambigs	Polymer	NumSeqs
# Minimum:	1	248	248	0	3	1
# 2.5%-tile:	1	252	252	0	3	3810
# 25%-tile:	1	252	252	0	4	38091
# Median: 	1	252	252	0	4	76181
# 75%-tile:	1	253	253	0	5	114271
# 97.5%-tile:	1	253	253	6	6	148552
# Maximum:	1	502	502	249	243	152360
# Mean:	1	252.811	252.811	0.70063	4.44854
# # of Seqs:	152360
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.summary
#
# It took 1 secs to summarize 152360 sequences.

# %%
mothur = mothur.screen.seqs(fasta='current', group='current', maxambig=0, maxlength=275)
# Out:
# mothur > screen.seqs(fasta=current,group=current,maxambig=0,maxlength=275)
# Using C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.fasta as input file for the fasta parameter.
# Using C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.contigs.groups as input file for the group parameter.
#
# Using 1 processors.
# Processing sequence: 100
# Processing sequence: 200
# Processing sequence: 300
# Processing sequence: 400
# Processing sequence: 500
# Processing sequence: 600
# Processing sequence: 700
# Processing sequence: 800
# Processing sequence: 900
# Processing sequence: 1000
# Processing sequence: 1100
# Processing sequence: 1200
# Processing sequence: 1300
# Processing sequence: 1400
# Processing sequence: 1500
# Processing sequence: 1600
# Processing sequence: 1700
# Processing sequence: 1800
# Processing sequence: 1900
# Processing sequence: 2000
# Processing sequence: 2100
# Processing sequence: 2200
# Processing sequence: 2300
# Processing sequence: 2400
# Processing sequence: 2500
# Processing sequence: 2600
# Processing sequence: 2700
# Processing sequence: 2800
# Processing sequence: 2900
# Processing sequence: 3000
# Processing sequence: 3100
# Processing sequence: 3200
# Processing sequence: 3300
# Processing sequence: 3400
# Processing sequence: 3500
# Processing sequence: 3600
# Processing sequence: 3700
# Processing sequence: 3800
# Processing sequence: 3900
# Processing sequence: 4000
# Processing sequence: 4100
# Processing sequence: 4200
# Processing sequence: 4300
# Processing sequence: 4400
# Processing sequence: 4500
# Processing sequence: 4600
# Processing sequence: 4700
# Processing sequence: 4800
# Processing sequence: 4900
# Processing sequence: 5000
# Processing sequence: 5100
# Processing sequence: 5200
# Processing sequence: 5300
# Processing sequence: 5400
# Processing sequence: 5500
# Processing sequence: 5600
# Processing sequence: 5700
# Processing sequence: 5800
# Processing sequence: 5900
# Processing sequence: 6000
# Processing sequence: 6100
# Processing sequence: 6200
# Processing sequence: 6300
# Processing sequence: 6400
# Processing sequence: 6500
# Processing sequence: 6600
# Processing sequence: 6700
# Processing sequence: 6800
# Processing sequence: 6900
# Processing sequence: 7000
# Processing sequence: 7100
# Processing sequence: 7200
# Processing sequence: 7300
# Processing sequence: 7400
# Processing sequence: 7500
# Processing sequence: 7600
# Processing sequence: 7700
# Processing sequence: 7800
# Processing sequence: 7900
# Processing sequence: 8000
# Processing sequence: 8100
# Processing sequence: 8200
# Processing sequence: 8300
# Processing sequence: 8400
# Processing sequence: 8500
# Processing sequence: 8600
# Processing sequence: 8700
# Processing sequence: 8800
# Processing sequence: 8900
# Processing sequence: 9000
# Processing sequence: 9100
# Processing sequence: 9200
# Processing sequence: 9300
# Processing sequence: 9400
# Processing sequence: 9500
# Processing sequence: 9600
# Processing sequence: 9700
# Processing sequence: 9800
# Processing sequence: 9900
# Processing sequence: 10000
# Processing sequence: 10100
# Processing sequence: 10200
# Processing sequence: 10300
# Processing sequence: 10400
# Processing sequence: 10500
# Processing sequence: 10600
# Processing sequence: 10700
# Processing sequence: 10800
# Processing sequence: 10900
# Processing sequence: 11000
# Processing sequence: 11100
# Processing sequence: 11200
# Processing sequence: 11300
# Processing sequence: 11400
# Processing sequence: 11500
# Processing sequence: 11600
# Processing sequence: 11700
# Processing sequence: 11800
# Processing sequence: 11900
# Processing sequence: 12000
# Processing sequence: 12100
# Processing sequence: 12200
# Processing sequence: 12300
# Processing sequence: 12400
# Processing sequence: 12500
# Processing sequence: 12600
# Processing sequence: 12700
# Processing sequence: 12800
# Processing sequence: 12900
# Processing sequence: 13000
# Processing sequence: 13100
# Processing sequence: 13200
# Processing sequence: 13300
# Processing sequence: 13400
# Processing sequence: 13500
# Processing sequence: 13600
# Processing sequence: 13700
# Processing sequence: 13800
# Processing sequence: 13900
# Processing sequence: 14000
# Processing sequence: 14100
# Processing sequence: 14200
# Processing sequence: 14300
# Processing sequence: 14400
# Processing sequence: 14500
# Processing sequence: 14600
# Processing sequence: 14700
# Processing sequence: 14800
# Processing sequence: 14900
# Processing sequence: 15000
# Processing sequence: 15100
# Processing sequence: 15200
# Processing sequence: 15300
# Processing sequence: 15400
# Processing sequence: 15500
# Processing sequence: 15600
# Processing sequence: 15700
# Processing sequence: 15800
# Processing sequence: 15900
# Processing sequence: 16000
# Processing sequence: 16100
# Processing sequence: 16200
# Processing sequence: 16300
# Processing sequence: 16400
# Processing sequence: 16500
# Processing sequence: 16600
# Processing sequence: 16700
# Processing sequence: 16800
# Processing sequence: 16900
# Processing sequence: 17000
# Processing sequence: 17100
# Processing sequence: 17200
# Processing sequence: 17300
# Processing sequence: 17400
# Processing sequence: 17500
# Processing sequence: 17600
# Processing sequence: 17700
# Processing sequence: 17800
# Processing sequence: 17900
# Processing sequence: 18000
# Processing sequence: 18100
# Processing sequence: 18200
# Processing sequence: 18300
# Processing sequence: 18400
# Processing sequence: 18500
# Processing sequence: 18600
# Processing sequence: 18700
# Processing sequence: 18800
# Processing sequence: 18900
# Processing sequence: 19000
# Processing sequence: 19100
# Processing sequence: 19200
# Processing sequence: 19300
# Processing sequence: 19400
# Processing sequence: 19500
# Processing sequence: 19600
# Processing sequence: 19700
# Processing sequence: 19800
# Processing sequence: 19900
# Processing sequence: 20000
# Processing sequence: 20100
# Processing sequence: 20200
# Processing sequence: 20300
# Processing sequence: 20400
# Processing sequence: 20500
# Processing sequence: 20600
# Processing sequence: 20700
# Processing sequence: 20800
# Processing sequence: 20900
# Processing sequence: 21000
# Processing sequence: 21100
# Processing sequence: 21200
# Processing sequence: 21300
# Processing sequence: 21400
# Processing sequence: 21500
# Processing sequence: 21600
# Processing sequence: 21700
# Processing sequence: 21800
# Processing sequence: 21900
# Processing sequence: 22000
# Processing sequence: 22100
# Processing sequence: 22200
# Processing sequence: 22300
# Processing sequence: 22400
# Processing sequence: 22500
# Processing sequence: 22600
# Processing sequence: 22700
# Processing sequence: 22800
# Processing sequence: 22900
# Processing sequence: 23000
# Processing sequence: 23100
# Processing sequence: 23200
# Processing sequence: 23300
# Processing sequence: 23400
# Processing sequence: 23500
# Processing sequence: 23600
# Processing sequence: 23700
# Processing sequence: 23800
# Processing sequence: 23900
# Processing sequence: 24000
# Processing sequence: 24100
# Processing sequence: 24200
# Processing sequence: 24300
# Processing sequence: 24400
# Processing sequence: 24500
# Processing sequence: 24600
# Processing sequence: 24700
# Processing sequence: 24800
# Processing sequence: 24900
# Processing sequence: 25000
# Processing sequence: 25100
# Processing sequence: 25200
# Processing sequence: 25300
# Processing sequence: 25400
# Processing sequence: 25500
# Processing sequence: 25600
# Processing sequence: 25700
# Processing sequence: 25800
# Processing sequence: 25900
# Processing sequence: 26000
# Processing sequence: 26100
# Processing sequence: 26200
# Processing sequence: 26300
# Processing sequence: 26400
# Processing sequence: 26500
# Processing sequence: 26600
# Processing sequence: 26700
# Processing sequence: 26800
# Processing sequence: 26900
# Processing sequence: 27000
# Processing sequence: 27100
# Processing sequence: 27200
# Processing sequence: 27300
# Processing sequence: 27400
# Processing sequence: 27500
# Processing sequence: 27600
# Processing sequence: 27700
# Processing sequence: 27800
# Processing sequence: 27900
# Processing sequence: 28000
# Processing sequence: 28100
# Processing sequence: 28200
# Processing sequence: 28300
# Processing sequence: 28400
# Processing sequence: 28500
# Processing sequence: 28600
# Processing sequence: 28700
# Processing sequence: 28800
# Processing sequence: 28900
# Processing sequence: 29000
# Processing sequence: 29100
# Processing sequence: 29200
# Processing sequence: 29300
# Processing sequence: 29400
# Processing sequence: 29500
# Processing sequence: 29600
# Processing sequence: 29700
# Processing sequence: 29800
# Processing sequence: 29900
# Processing sequence: 30000
# Processing sequence: 30100
# Processing sequence: 30200
# Processing sequence: 30300
# Processing sequence: 30400
# Processing sequence: 30500
# Processing sequence: 30600
# Processing sequence: 30700
# Processing sequence: 30800
# Processing sequence: 30900
# Processing sequence: 31000
# Processing sequence: 31100
# Processing sequence: 31200
# Processing sequence: 31300
# Processing sequence: 31400
# Processing sequence: 31500
# Processing sequence: 31600
# Processing sequence: 31700
# Processing sequence: 31800
# Processing sequence: 31900
# Processing sequence: 32000
# Processing sequence: 32100
# Processing sequence: 32200
# Processing sequence: 32300
# Processing sequence: 32400
# Processing sequence: 32500
# Processing sequence: 32600
# Processing sequence: 32700
# Processing sequence: 32800
# Processing sequence: 32900
# Processing sequence: 33000
# Processing sequence: 33100
# Processing sequence: 33200
# Processing sequence: 33300
# Processing sequence: 33400
# Processing sequence: 33500
# Processing sequence: 33600
# Processing sequence: 33700
# Processing sequence: 33800
# Processing sequence: 33900
# Processing sequence: 34000
# Processing sequence: 34100
# Processing sequence: 34200
# Processing sequence: 34300
# Processing sequence: 34400
# Processing sequence: 34500
# Processing sequence: 34600
# Processing sequence: 34700
# Processing sequence: 34800
# Processing sequence: 34900
# Processing sequence: 35000
# Processing sequence: 35100
# Processing sequence: 35200
# Processing sequence: 35300
# Processing sequence: 35400
# Processing sequence: 35500
# Processing sequence: 35600
# Processing sequence: 35700
# Processing sequence: 35800
# Processing sequence: 35900
# Processing sequence: 36000
# Processing sequence: 36100
# Processing sequence: 36200
# Processing sequence: 36300
# Processing sequence: 36400
# Processing sequence: 36500
# Processing sequence: 36600
# Processing sequence: 36700
# Processing sequence: 36800
# Processing sequence: 36900
# Processing sequence: 37000
# Processing sequence: 37100
# Processing sequence: 37200
# Processing sequence: 37300
# Processing sequence: 37400
# Processing sequence: 37500
# Processing sequence: 37600
# Processing sequence: 37700
# Processing sequence: 37800
# Processing sequence: 37900
# Processing sequence: 38000
# Processing sequence: 38100
# Processing sequence: 38200
# Processing sequence: 38300
# Processing sequence: 38400
# Processing sequence: 38500
# Processing sequence: 38600
# Processing sequence: 38700
# Processing sequence: 38800
# Processing sequence: 38900
# Processing sequence: 39000
# Processing sequence: 39100
# Processing sequence: 39200
# Processing sequence: 39300
# Processing sequence: 39400
# Processing sequence: 39500
# Processing sequence: 39600
# Processing sequence: 39700
# Processing sequence: 39800
# Processing sequence: 39900
# Processing sequence: 40000
# Processing sequence: 40100
# Processing sequence: 40200
# Processing sequence: 40300
# Processing sequence: 40400
# Processing sequence: 40500
# Processing sequence: 40600
# Processing sequence: 40700
# Processing sequence: 40800
# Processing sequence: 40900
# Processing sequence: 41000
# Processing sequence: 41100
# Processing sequence: 41200
# Processing sequence: 41300
# Processing sequence: 41400
# Processing sequence: 41500
# Processing sequence: 41600
# Processing sequence: 41700
# Processing sequence: 41800
# Processing sequence: 41900
# Processing sequence: 42000
# Processing sequence: 42100
# Processing sequence: 42200
# Processing sequence: 42300
# Processing sequence: 42400
# Processing sequence: 42500
# Processing sequence: 42600
# Processing sequence: 42700
# Processing sequence: 42800
# Processing sequence: 42900
# Processing sequence: 43000
# Processing sequence: 43100
# Processing sequence: 43200
# Processing sequence: 43300
# Processing sequence: 43400
# Processing sequence: 43500
# Processing sequence: 43600
# Processing sequence: 43700
# Processing sequence: 43800
# Processing sequence: 43900
# Processing sequence: 44000
# Processing sequence: 44100
# Processing sequence: 44200
# Processing sequence: 44300
# Processing sequence: 44400
# Processing sequence: 44500
# Processing sequence: 44600
# Processing sequence: 44700
# Processing sequence: 44800
# Processing sequence: 44900
# Processing sequence: 45000
# Processing sequence: 45100
# Processing sequence: 45200
# Processing sequence: 45300
# Processing sequence: 45400
# Processing sequence: 45500
# Processing sequence: 45600
# Processing sequence: 45700
# Processing sequence: 45800
# Processing sequence: 45900
# Processing sequence: 46000
# Processing sequence: 46100
# Processing sequence: 46200
# Processing sequence: 46300
# Processing sequence: 46400
# Processing sequence: 46500
# Processing sequence: 46600
# Processing sequence: 46700
# Processing sequence: 46800
# Processing sequence: 46900
# Processing sequence: 47000
# Processing sequence: 47100
# Processing sequence: 47200
# Processing sequence: 47300
# Processing sequence: 47400
# Processing sequence: 47500
# Processing sequence: 47600
# Processing sequence: 47700
# Processing sequence: 47800
# Processing sequence: 47900
# Processing sequence: 48000
# Processing sequence: 48100
# Processing sequence: 48200
# Processing sequence: 48300
# Processing sequence: 48400
# Processing sequence: 48500
# Processing sequence: 48600
# Processing sequence: 48700
# Processing sequence: 48800
# Processing sequence: 48900
# Processing sequence: 49000
# Processing sequence: 49100
# Processing sequence: 49200
# Processing sequence: 49300
# Processing sequence: 49400
# Processing sequence: 49500
# Processing sequence: 49600
# Processing sequence: 49700
# Processing sequence: 49800
# Processing sequence: 49900
# Processing sequence: 50000
# Processing sequence: 50100
# Processing sequence: 50200
# Processing sequence: 50300
# Processing sequence: 50400
# Processing sequence: 50500
# Processing sequence: 50600
# Processing sequence: 50700
# Processing sequence: 50800
# Processing sequence: 50900
# Processing sequence: 51000
# Processing sequence: 51100
# Processing sequence: 51200
# Processing sequence: 51300
# Processing sequence: 51400
# Processing sequence: 51500
# Processing sequence: 51600
# Processing sequence: 51700
# Processing sequence: 51800
# Processing sequence: 51900
# Processing sequence: 52000
# Processing sequence: 52100
# Processing sequence: 52200
# Processing sequence: 52300
# Processing sequence: 52400
# Processing sequence: 52500
# Processing sequence: 52600
# Processing sequence: 52700
# Processing sequence: 52800
# Processing sequence: 52900
# Processing sequence: 53000
# Processing sequence: 53100
# Processing sequence: 53200
# Processing sequence: 53300
# Processing sequence: 53400
# Processing sequence: 53500
# Processing sequence: 53600
# Processing sequence: 53700
# Processing sequence: 53800
# Processing sequence: 53900
# Processing sequence: 54000
# Processing sequence: 54100
# Processing sequence: 54200
# Processing sequence: 54300
# Processing sequence: 54400
# Processing sequence: 54500
# Processing sequence: 54600
# Processing sequence: 54700
# Processing sequence: 54800
# Processing sequence: 54900
# Processing sequence: 55000
# Processing sequence: 55100
# Processing sequence: 55200
# Processing sequence: 55300
# Processing sequence: 55400
# Processing sequence: 55500
# Processing sequence: 55600
# Processing sequence: 55700
# Processing sequence: 55800
# Processing sequence: 55900
# Processing sequence: 56000
# Processing sequence: 56100
# Processing sequence: 56200
# Processing sequence: 56300
# Processing sequence: 56400
# Processing sequence: 56500
# Processing sequence: 56600
# Processing sequence: 56700
# Processing sequence: 56800
# Processing sequence: 56900
# Processing sequence: 57000
# Processing sequence: 57100
# Processing sequence: 57200
# Processing sequence: 57300
# Processing sequence: 57400
# Processing sequence: 57500
# Processing sequence: 57600
# Processing sequence: 57700
# Processing sequence: 57800
# Processing sequence: 57900
# Processing sequence: 58000
# Processing sequence: 58100
# Processing sequence: 58200
# Processing sequence: 58300
# Processing sequence: 58400
# Processing sequence: 58500
# Processing sequence: 58600
# Processing sequence: 58700
# Processing sequence: 58800
# Processing sequence: 58900
# Processing sequence: 59000
# Processing sequence: 59100
# Processing sequence: 59200
# Processing sequence: 59300
# Processing sequence: 59400
# Processing sequence: 59500
# Processing sequence: 59600
# Processing sequence: 59700
# Processing sequence: 59800
# Processing sequence: 59900
# Processing sequence: 60000
# Processing sequence: 60100
# Processing sequence: 60200
# Processing sequence: 60300
# Processing sequence: 60400
# Processing sequence: 60500
# Processing sequence: 60600
# Processing sequence: 60700
# Processing sequence: 60800
# Processing sequence: 60900
# Processing sequence: 61000
# Processing sequence: 61100
# Processing sequence: 61200
# Processing sequence: 61300
# Processing sequence: 61400
# Processing sequence: 61500
# Processing sequence: 61600
# Processing sequence: 61700
# Processing sequence: 61800
# Processing sequence: 61900
# Processing sequence: 62000
# Processing sequence: 62100
# Processing sequence: 62200
# Processing sequence: 62300
# Processing sequence: 62400
# Processing sequence: 62500
# Processing sequence: 62600
# Processing sequence: 62700
# Processing sequence: 62800
# Processing sequence: 62900
# Processing sequence: 63000
# Processing sequence: 63100
# Processing sequence: 63200
# Processing sequence: 63300
# Processing sequence: 63400
# Processing sequence: 63500
# Processing sequence: 63600
# Processing sequence: 63700
# Processing sequence: 63800
# Processing sequence: 63900
# Processing sequence: 64000
# Processing sequence: 64100
# Processing sequence: 64200
# Processing sequence: 64300
# Processing sequence: 64400
# Processing sequence: 64500
# Processing sequence: 64600
# Processing sequence: 64700
# Processing sequence: 64800
# Processing sequence: 64900
# Processing sequence: 65000
# Processing sequence: 65100
# Processing sequence: 65200
# Processing sequence: 65300
# Processing sequence: 65400
# Processing sequence: 65500
# Processing sequence: 65600
# Processing sequence: 65700
# Processing sequence: 65800
# Processing sequence: 65900
# Processing sequence: 66000
# Processing sequence: 66100
# Processing sequence: 66200
# Processing sequence: 66300
# Processing sequence: 66400
# Processing sequence: 66500
# Processing sequence: 66600
# Processing sequence: 66700
# Processing sequence: 66800
# Processing sequence: 66900
# Processing sequence: 67000
# Processing sequence: 67100
# Processing sequence: 67200
# Processing sequence: 67300
# Processing sequence: 67400
# Processing sequence: 67500
# Processing sequence: 67600
# Processing sequence: 67700
# Processing sequence: 67800
# Processing sequence: 67900
# Processing sequence: 68000
# Processing sequence: 68100
# Processing sequence: 68200
# Processing sequence: 68300
# Processing sequence: 68400
# Processing sequence: 68500
# Processing sequence: 68600
# Processing sequence: 68700
# Processing sequence: 68800
# Processing sequence: 68900
# Processing sequence: 69000
# Processing sequence: 69100
# Processing sequence: 69200
# Processing sequence: 69300
# Processing sequence: 69400
# Processing sequence: 69500
# Processing sequence: 69600
# Processing sequence: 69700
# Processing sequence: 69800
# Processing sequence: 69900
# Processing sequence: 70000
# Processing sequence: 70100
# Processing sequence: 70200
# Processing sequence: 70300
# Processing sequence: 70400
# Processing sequence: 70500
# Processing sequence: 70600
# Processing sequence: 70700
# Processing sequence: 70800
# Processing sequence: 70900
# Processing sequence: 71000
# Processing sequence: 71100
# Processing sequence: 71200
# Processing sequence: 71300
# Processing sequence: 71400
# Processing sequence: 71500
# Processing sequence: 71600
# Processing sequence: 71700
# Processing sequence: 71800
# Processing sequence: 71900
# Processing sequence: 72000
# Processing sequence: 72100
# Processing sequence: 72200
# Processing sequence: 72300
# Processing sequence: 72400
# Processing sequence: 72500
# Processing sequence: 72600
# Processing sequence: 72700
# Processing sequence: 72800
# Processing sequence: 72900
# Processing sequence: 73000
# Processing sequence: 73100
# Processing sequence: 73200
# Processing sequence: 73300
# Processing sequence: 73400
# Processing sequence: 73500
# Processing sequence: 73600
# Processing sequence: 73700
# Processing sequence: 73800
# Processing sequence: 73900
# Processing sequence: 74000
# Processing sequence: 74100
# Processing sequence: 74200
# Processing sequence: 74300
# Processing sequence: 74400
# Processing sequence: 74500
# Processing sequence: 74600
# Processing sequence: 74700
# Processing sequence: 74800
# Processing sequence: 74900
# Processing sequence: 75000
# Processing sequence: 75100
# Processing sequence: 75200
# Processing sequence: 75300
# Processing sequence: 75400
# Processing sequence: 75500
# Processing sequence: 75600
# Processing sequence: 75700
# Processing sequence: 75800
# Processing sequence: 75900
# Processing sequence: 76000
# Processing sequence: 76100
# Processing sequence: 76200
# Processing sequence: 76300
# Processing sequence: 76400
# Processing sequence: 76500
# Processing sequence: 76600
# Processing sequence: 76700
# Processing sequence: 76800
# Processing sequence: 76900
# Processing sequence: 77000
# Processing sequence: 77100
# Processing sequence: 77200
# Processing sequence: 77300
# Processing sequence: 77400
# Processing sequence: 77500
# Processing sequence: 77600
# Processing sequence: 77700
# Processing sequence: 77800
# Processing sequence: 77900
# Processing sequence: 78000
# Processing sequence: 78100
# Processing sequence: 78200
# Processing sequence: 78300
# Processing sequence: 78400
# Processing sequence: 78500
# Processing sequence: 78600
# Processing sequence: 78700
# Processing sequence: 78800
# Processing sequence: 78900
# Processing sequence: 79000
# Processing sequence: 79100
# Processing sequence: 79200
# Processing sequence: 79300
# Processing sequence: 79400
# Processing sequence: 79500
# Processing sequence: 79600
# Processing sequence: 79700
# Processing sequence: 79800
# Processing sequence: 79900
# Processing sequence: 80000
# Processing sequence: 80100
# Processing sequence: 80200
# Processing sequence: 80300
# Processing sequence: 80400
# Processing sequence: 80500
# Processing sequence: 80600
# Processing sequence: 80700
# Processing sequence: 80800
# Processing sequence: 80900
# Processing sequence: 81000
# Processing sequence: 81100
# Processing sequence: 81200
# Processing sequence: 81300
# Processing sequence: 81400
# Processing sequence: 81500
# Processing sequence: 81600
# Processing sequence: 81700
# Processing sequence: 81800
# Processing sequence: 81900
# Processing sequence: 82000
# Processing sequence: 82100
# Processing sequence: 82200
# Processing sequence: 82300
# Processing sequence: 82400
# Processing sequence: 82500
# Processing sequence: 82600
# Processing sequence: 82700
# Processing sequence: 82800
# Processing sequence: 82900
# Processing sequence: 83000
# Processing sequence: 83100
# Processing sequence: 83200
# Processing sequence: 83300
# Processing sequence: 83400
# Processing sequence: 83500
# Processing sequence: 83600
# Processing sequence: 83700
# Processing sequence: 83800
# Processing sequence: 83900
# Processing sequence: 84000
# Processing sequence: 84100
# Processing sequence: 84200
# Processing sequence: 84300
# Processing sequence: 84400
# Processing sequence: 84500
# Processing sequence: 84600
# Processing sequence: 84700
# Processing sequence: 84800
# Processing sequence: 84900
# Processing sequence: 85000
# Processing sequence: 85100
# Processing sequence: 85200
# Processing sequence: 85300
# Processing sequence: 85400
# Processing sequence: 85500
# Processing sequence: 85600
# Processing sequence: 85700
# Processing sequence: 85800
# Processing sequence: 85900
# Processing sequence: 86000
# Processing sequence: 86100
# Processing sequence: 86200
# Processing sequence: 86300
# Processing sequence: 86400
# Processing sequence: 86500
# Processing sequence: 86600
# Processing sequence: 86700
# Processing sequence: 86800
# Processing sequence: 86900
# Processing sequence: 87000
# Processing sequence: 87100
# Processing sequence: 87200
# Processing sequence: 87300
# Processing sequence: 87400
# Processing sequence: 87500
# Processing sequence: 87600
# Processing sequence: 87700
# Processing sequence: 87800
# Processing sequence: 87900
# Processing sequence: 88000
# Processing sequence: 88100
# Processing sequence: 88200
# Processing sequence: 88300
# Processing sequence: 88400
# Processing sequence: 88500
# Processing sequence: 88600
# Processing sequence: 88700
# Processing sequence: 88800
# Processing sequence: 88900
# Processing sequence: 89000
# Processing sequence: 89100
# Processing sequence: 89200
# Processing sequence: 89300
# Processing sequence: 89400
# Processing sequence: 89500
# Processing sequence: 89600
# Processing sequence: 89700
# Processing sequence: 89800
# Processing sequence: 89900
# Processing sequence: 90000
# Processing sequence: 90100
# Processing sequence: 90200
# Processing sequence: 90300
# Processing sequence: 90400
# Processing sequence: 90500
# Processing sequence: 90600
# Processing sequence: 90700
# Processing sequence: 90800
# Processing sequence: 90900
# Processing sequence: 91000
# Processing sequence: 91100
# Processing sequence: 91200
# Processing sequence: 91300
# Processing sequence: 91400
# Processing sequence: 91500
# Processing sequence: 91600
# Processing sequence: 91700
# Processing sequence: 91800
# Processing sequence: 91900
# Processing sequence: 92000
# Processing sequence: 92100
# Processing sequence: 92200
# Processing sequence: 92300
# Processing sequence: 92400
# Processing sequence: 92500
# Processing sequence: 92600
# Processing sequence: 92700
# Processing sequence: 92800
# Processing sequence: 92900
# Processing sequence: 93000
# Processing sequence: 93100
# Processing sequence: 93200
# Processing sequence: 93300
# Processing sequence: 93400
# Processing sequence: 93500
# Processing sequence: 93600
# Processing sequence: 93700
# Processing sequence: 93800
# Processing sequence: 93900
# Processing sequence: 94000
# Processing sequence: 94100
# Processing sequence: 94200
# Processing sequence: 94300
# Processing sequence: 94400
# Processing sequence: 94500
# Processing sequence: 94600
# Processing sequence: 94700
# Processing sequence: 94800
# Processing sequence: 94900
# Processing sequence: 95000
# Processing sequence: 95100
# Processing sequence: 95200
# Processing sequence: 95300
# Processing sequence: 95400
# Processing sequence: 95500
# Processing sequence: 95600
# Processing sequence: 95700
# Processing sequence: 95800
# Processing sequence: 95900
# Processing sequence: 96000
# Processing sequence: 96100
# Processing sequence: 96200
# Processing sequence: 96300
# Processing sequence: 96400
# Processing sequence: 96500
# Processing sequence: 96600
# Processing sequence: 96700
# Processing sequence: 96800
# Processing sequence: 96900
# Processing sequence: 97000
# Processing sequence: 97100
# Processing sequence: 97200
# Processing sequence: 97300
# Processing sequence: 97400
# Processing sequence: 97500
# Processing sequence: 97600
# Processing sequence: 97700
# Processing sequence: 97800
# Processing sequence: 97900
# Processing sequence: 98000
# Processing sequence: 98100
# Processing sequence: 98200
# Processing sequence: 98300
# Processing sequence: 98400
# Processing sequence: 98500
# Processing sequence: 98600
# Processing sequence: 98700
# Processing sequence: 98800
# Processing sequence: 98900
# Processing sequence: 99000
# Processing sequence: 99100
# Processing sequence: 99200
# Processing sequence: 99300
# Processing sequence: 99400
# Processing sequence: 99500
# Processing sequence: 99600
# Processing sequence: 99700
# Processing sequence: 99800
# Processing sequence: 99900
# Processing sequence: 100000
# Processing sequence: 100100
# Processing sequence: 100200
# Processing sequence: 100300
# Processing sequence: 100400
# Processing sequence: 100500
# Processing sequence: 100600
# Processing sequence: 100700
# Processing sequence: 100800
# Processing sequence: 100900
# Processing sequence: 101000
# Processing sequence: 101100
# Processing sequence: 101200
# Processing sequence: 101300
# Processing sequence: 101400
# Processing sequence: 101500
# Processing sequence: 101600
# Processing sequence: 101700
# Processing sequence: 101800
# Processing sequence: 101900
# Processing sequence: 102000
# Processing sequence: 102100
# Processing sequence: 102200
# Processing sequence: 102300
# Processing sequence: 102400
# Processing sequence: 102500
# Processing sequence: 102600
# Processing sequence: 102700
# Processing sequence: 102800
# Processing sequence: 102900
# Processing sequence: 103000
# Processing sequence: 103100
# Processing sequence: 103200
# Processing sequence: 103300
# Processing sequence: 103400
# Processing sequence: 103500
# Processing sequence: 103600
# Processing sequence: 103700
# Processing sequence: 103800
# Processing sequence: 103900
# Processing sequence: 104000
# Processing sequence: 104100
# Processing sequence: 104200
# Processing sequence: 104300
# Processing sequence: 104400
# Processing sequence: 104500
# Processing sequence: 104600
# Processing sequence: 104700
# Processing sequence: 104800
# Processing sequence: 104900
# Processing sequence: 105000
# Processing sequence: 105100
# Processing sequence: 105200
# Processing sequence: 105300
# Processing sequence: 105400
# Processing sequence: 105500
# Processing sequence: 105600
# Processing sequence: 105700
# Processing sequence: 105800
# Processing sequence: 105900
# Processing sequence: 106000
# Processing sequence: 106100
# Processing sequence: 106200
# Processing sequence: 106300
# Processing sequence: 106400
# Processing sequence: 106500
# Processing sequence: 106600
# Processing sequence: 106700
# Processing sequence: 106800
# Processing sequence: 106900
# Processing sequence: 107000
# Processing sequence: 107100
# Processing sequence: 107200
# Processing sequence: 107300
# Processing sequence: 107400
# Processing sequence: 107500
# Processing sequence: 107600
# Processing sequence: 107700
# Processing sequence: 107800
# Processing sequence: 107900
# Processing sequence: 108000
# Processing sequence: 108100
# Processing sequence: 108200
# Processing sequence: 108300
# Processing sequence: 108400
# Processing sequence: 108500
# Processing sequence: 108600
# Processing sequence: 108700
# Processing sequence: 108800
# Processing sequence: 108900
# Processing sequence: 109000
# Processing sequence: 109100
# Processing sequence: 109200
# Processing sequence: 109300
# Processing sequence: 109400
# Processing sequence: 109500
# Processing sequence: 109600
# Processing sequence: 109700
# Processing sequence: 109800
# Processing sequence: 109900
# Processing sequence: 110000
# Processing sequence: 110100
# Processing sequence: 110200
# Processing sequence: 110300
# Processing sequence: 110400
# Processing sequence: 110500
# Processing sequence: 110600
# Processing sequence: 110700
# Processing sequence: 110800
# Processing sequence: 110900
# Processing sequence: 111000
# Processing sequence: 111100
# Processing sequence: 111200
# Processing sequence: 111300
# Processing sequence: 111400
# Processing sequence: 111500
# Processing sequence: 111600
# Processing sequence: 111700
# Processing sequence: 111800
# Processing sequence: 111900
# Processing sequence: 112000
# Processing sequence: 112100
# Processing sequence: 112200
# Processing sequence: 112300
# Processing sequence: 112400
# Processing sequence: 112500
# Processing sequence: 112600
# Processing sequence: 112700
# Processing sequence: 112800
# Processing sequence: 112900
# Processing sequence: 113000
# Processing sequence: 113100
# Processing sequence: 113200
# Processing sequence: 113300
# Processing sequence: 113400
# Processing sequence: 113500
# Processing sequence: 113600
# Processing sequence: 113700
# Processing sequence: 113800
# Processing sequence: 113900
# Processing sequence: 114000
# Processing sequence: 114100
# Processing sequence: 114200
# Processing sequence: 114300
# Processing sequence: 114400
# Processing sequence: 114500
# Processing sequence: 114600
# Processing sequence: 114700
# Processing sequence: 114800
# Processing sequence: 114900
# Processing sequence: 115000
# Processing sequence: 115100
# Processing sequence: 115200
# Processing sequence: 115300
# Processing sequence: 115400
# Processing sequence: 115500
# Processing sequence: 115600
# Processing sequence: 115700
# Processing sequence: 115800
# Processing sequence: 115900
# Processing sequence: 116000
# Processing sequence: 116100
# Processing sequence: 116200
# Processing sequence: 116300
# Processing sequence: 116400
# Processing sequence: 116500
# Processing sequence: 116600
# Processing sequence: 116700
# Processing sequence: 116800
# Processing sequence: 116900
# Processing sequence: 117000
# Processing sequence: 117100
# Processing sequence: 117200
# Processing sequence: 117300
# Processing sequence: 117400
# Processing sequence: 117500
# Processing sequence: 117600
# Processing sequence: 117700
# Processing sequence: 117800
# Processing sequence: 117900
# Processing sequence: 118000
# Processing sequence: 118100
# Processing sequence: 118200
# Processing sequence: 118300
# Processing sequence: 118400
# Processing sequence: 118500
# Processing sequence: 118600
# Processing sequence: 118700
# Processing sequence: 118800
# Processing sequence: 118900
# Processing sequence: 119000
# Processing sequence: 119100
# Processing sequence: 119200
# Processing sequence: 119300
# Processing sequence: 119400
# Processing sequence: 119500
# Processing sequence: 119600
# Processing sequence: 119700
# Processing sequence: 119800
# Processing sequence: 119900
# Processing sequence: 120000
# Processing sequence: 120100
# Processing sequence: 120200
# Processing sequence: 120300
# Processing sequence: 120400
# Processing sequence: 120500
# Processing sequence: 120600
# Processing sequence: 120700
# Processing sequence: 120800
# Processing sequence: 120900
# Processing sequence: 121000
# Processing sequence: 121100
# Processing sequence: 121200
# Processing sequence: 121300
# Processing sequence: 121400
# Processing sequence: 121500
# Processing sequence: 121600
# Processing sequence: 121700
# Processing sequence: 121800
# Processing sequence: 121900
# Processing sequence: 122000
# Processing sequence: 122100
# Processing sequence: 122200
# Processing sequence: 122300
# Processing sequence: 122400
# Processing sequence: 122500
# Processing sequence: 122600
# Processing sequence: 122700
# Processing sequence: 122800
# Processing sequence: 122900
# Processing sequence: 123000
# Processing sequence: 123100
# Processing sequence: 123200
# Processing sequence: 123300
# Processing sequence: 123400
# Processing sequence: 123500
# Processing sequence: 123600
# Processing sequence: 123700
# Processing sequence: 123800
# Processing sequence: 123900
# Processing sequence: 124000
# Processing sequence: 124100
# Processing sequence: 124200
# Processing sequence: 124300
# Processing sequence: 124400
# Processing sequence: 124500
# Processing sequence: 124600
# Processing sequence: 124700
# Processing sequence: 124800
# Processing sequence: 124900
# Processing sequence: 125000
# Processing sequence: 125100
# Processing sequence: 125200
# Processing sequence: 125300
# Processing sequence: 125400
# Processing sequence: 125500
# Processing sequence: 125600
# Processing sequence: 125700
# Processing sequence: 125800
# Processing sequence: 125900
# Processing sequence: 126000
# Processing sequence: 126100
# Processing sequence: 126200
# Processing sequence: 126300
# Processing sequence: 126400
# Processing sequence: 126500
# Processing sequence: 126600
# Processing sequence: 126700
# Processing sequence: 126800
# Processing sequence: 126900
# Processing sequence: 127000
# Processing sequence: 127100
# Processing sequence: 127200
# Processing sequence: 127300
# Processing sequence: 127400
# Processing sequence: 127500
# Processing sequence: 127600
# Processing sequence: 127700
# Processing sequence: 127800
# Processing sequence: 127900
# Processing sequence: 128000
# Processing sequence: 128100
# Processing sequence: 128200
# Processing sequence: 128300
# Processing sequence: 128400
# Processing sequence: 128500
# Processing sequence: 128600
# Processing sequence: 128700
# Processing sequence: 128800
# Processing sequence: 128900
# Processing sequence: 129000
# Processing sequence: 129100
# Processing sequence: 129200
# Processing sequence: 129300
# Processing sequence: 129400
# Processing sequence: 129500
# Processing sequence: 129600
# Processing sequence: 129700
# Processing sequence: 129800
# Processing sequence: 129900
# Processing sequence: 130000
# Processing sequence: 130100
# Processing sequence: 130200
# Processing sequence: 130300
# Processing sequence: 130400
# Processing sequence: 130500
# Processing sequence: 130600
# Processing sequence: 130700
# Processing sequence: 130800
# Processing sequence: 130900
# Processing sequence: 131000
# Processing sequence: 131100
# Processing sequence: 131200
# Processing sequence: 131300
# Processing sequence: 131400
# Processing sequence: 131500
# Processing sequence: 131600
# Processing sequence: 131700
# Processing sequence: 131800
# Processing sequence: 131900
# Processing sequence: 132000
# Processing sequence: 132100
# Processing sequence: 132200
# Processing sequence: 132300
# Processing sequence: 132400
# Processing sequence: 132500
# Processing sequence: 132600
# Processing sequence: 132700
# Processing sequence: 132800
# Processing sequence: 132900
# Processing sequence: 133000
# Processing sequence: 133100
# Processing sequence: 133200
# Processing sequence: 133300
# Processing sequence: 133400
# Processing sequence: 133500
# Processing sequence: 133600
# Processing sequence: 133700
# Processing sequence: 133800
# Processing sequence: 133900
# Processing sequence: 134000
# Processing sequence: 134100
# Processing sequence: 134200
# Processing sequence: 134300
# Processing sequence: 134400
# Processing sequence: 134500
# Processing sequence: 134600
# Processing sequence: 134700
# Processing sequence: 134800
# Processing sequence: 134900
# Processing sequence: 135000
# Processing sequence: 135100
# Processing sequence: 135200
# Processing sequence: 135300
# Processing sequence: 135400
# Processing sequence: 135500
# Processing sequence: 135600
# Processing sequence: 135700
# Processing sequence: 135800
# Processing sequence: 135900
# Processing sequence: 136000
# Processing sequence: 136100
# Processing sequence: 136200
# Processing sequence: 136300
# Processing sequence: 136400
# Processing sequence: 136500
# Processing sequence: 136600
# Processing sequence: 136700
# Processing sequence: 136800
# Processing sequence: 136900
# Processing sequence: 137000
# Processing sequence: 137100
# Processing sequence: 137200
# Processing sequence: 137300
# Processing sequence: 137400
# Processing sequence: 137500
# Processing sequence: 137600
# Processing sequence: 137700
# Processing sequence: 137800
# Processing sequence: 137900
# Processing sequence: 138000
# Processing sequence: 138100
# Processing sequence: 138200
# Processing sequence: 138300
# Processing sequence: 138400
# Processing sequence: 138500
# Processing sequence: 138600
# Processing sequence: 138700
# Processing sequence: 138800
# Processing sequence: 138900
# Processing sequence: 139000
# Processing sequence: 139100
# Processing sequence: 139200
# Processing sequence: 139300
# Processing sequence: 139400
# Processing sequence: 139500
# Processing sequence: 139600
# Processing sequence: 139700
# Processing sequence: 139800
# Processing sequence: 139900
# Processing sequence: 140000
# Processing sequence: 140100
# Processing sequence: 140200
# Processing sequence: 140300
# Processing sequence: 140400
# Processing sequence: 140500
# Processing sequence: 140600
# Processing sequence: 140700
# Processing sequence: 140800
# Processing sequence: 140900
# Processing sequence: 141000
# Processing sequence: 141100
# Processing sequence: 141200
# Processing sequence: 141300
# Processing sequence: 141400
# Processing sequence: 141500
# Processing sequence: 141600
# Processing sequence: 141700
# Processing sequence: 141800
# Processing sequence: 141900
# Processing sequence: 142000
# Processing sequence: 142100
# Processing sequence: 142200
# Processing sequence: 142300
# Processing sequence: 142400
# Processing sequence: 142500
# Processing sequence: 142600
# Processing sequence: 142700
# Processing sequence: 142800
# Processing sequence: 142900
# Processing sequence: 143000
# Processing sequence: 143100
# Processing sequence: 143200
# Processing sequence: 143300
# Processing sequence: 143400
# Processing sequence: 143500
# Processing sequence: 143600
# Processing sequence: 143700
# Processing sequence: 143800
# Processing sequence: 143900
# Processing sequence: 144000
# Processing sequence: 144100
# Processing sequence: 144200
# Processing sequence: 144300
# Processing sequence: 144400
# Processing sequence: 144500
# Processing sequence: 144600
# Processing sequence: 144700
# Processing sequence: 144800
# Processing sequence: 144900
# Processing sequence: 145000
# Processing sequence: 145100
# Processing sequence: 145200
# Processing sequence: 145300
# Processing sequence: 145400
# Processing sequence: 145500
# Processing sequence: 145600
# Processing sequence: 145700
# Processing sequence: 145800
# Processing sequence: 145900
# Processing sequence: 146000
# Processing sequence: 146100
# Processing sequence: 146200
# Processing sequence: 146300
# Processing sequence: 146400
# Processing sequence: 146500
# Processing sequence: 146600
# Processing sequence: 146700
# Processing sequence: 146800
# Processing sequence: 146900
# Processing sequence: 147000
# Processing sequence: 147100
# Processing sequence: 147200
# Processing sequence: 147300
# Processing sequence: 147400
# Processing sequence: 147500
# Processing sequence: 147600
# Processing sequence: 147700
# Processing sequence: 147800
# Processing sequence: 147900
# Processing sequence: 148000
# Processing sequence: 148100
# Processing sequence: 148200
# Processing sequence: 148300
# Processing sequence: 148400
# Processing sequence: 148500
# Processing sequence: 148600
# Processing sequence: 148700
# Processing sequence: 148800
# Processing sequence: 148900
# Processing sequence: 149000
# Processing sequence: 149100
# Processing sequence: 149200
# Processing sequence: 149300
# Processing sequence: 149400
# Processing sequence: 149500
# Processing sequence: 149600
# Processing sequence: 149700
# Processing sequence: 149800
# Processing sequence: 149900
# Processing sequence: 150000
# Processing sequence: 150100
# Processing sequence: 150200
# Processing sequence: 150300
# Processing sequence: 150400
# Processing sequence: 150500
# Processing sequence: 150600
# Processing sequence: 150700
# Processing sequence: 150800
# Processing sequence: 150900
# Processing sequence: 151000
# Processing sequence: 151100
# Processing sequence: 151200
# Processing sequence: 151300
# Processing sequence: 151400
# Processing sequence: 151500
# Processing sequence: 151600
# Processing sequence: 151700
# Processing sequence: 151800
# Processing sequence: 151900
# Processing sequence: 152000
# Processing sequence: 152100
# Processing sequence: 152200
# Processing sequence: 152300
# Processing sequence: 152360
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.fasta
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.bad.accnos
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.contigs.good.groups
#
#
# It took 2 secs to screen 152360 sequences.

# %%
mothur = mothur.unique.seqs(fasta='stability.trim.contigs.good.fasta')
# Out:
# mothur > unique.seqs(fasta=stability.trim.contigs.good.fasta)
# 1000	351
# 2000	590
# 3000	784
# 4000	991
# 5000	1196
# 6000	1400
# 7000	1611
# 8000	1786
# 9000	1952
# 10000	2101
# 11000	2270
# 12000	2433
# 13000	2605
# 14000	2767
# 15000	2934
# 16000	3086
# 17000	3260
# 18000	3416
# 19000	3563
# 20000	3705
# 21000	3862
# 22000	3995
# 23000	4139
# 24000	4263
# 25000	4400
# 26000	4525
# 27000	4660
# 28000	4807
# 29000	4952
# 30000	5116
# 31000	5272
# 32000	5419
# 33000	5554
# 34000	5709
# 35000	5856
# 36000	5987
# 37000	6110
# 38000	6241
# 39000	6375
# 40000	6521
# 41000	6645
# 42000	6798
# 43000	6915
# 44000	7019
# 45000	7153
# 46000	7280
# 47000	7416
# 48000	7529
# 49000	7642
# 50000	7762
# 51000	7889
# 52000	7998
# 53000	8109
# 54000	8240
# 55000	8359
# 56000	8476
# 57000	8603
# 58000	8738
# 59000	8863
# 60000	8992
# 61000	9112
# 62000	9234
# 63000	9356
# 64000	9492
# 65000	9616
# 66000	9708
# 67000	9816
# 68000	9943
# 69000	10079
# 70000	10235
# 71000	10366
# 72000	10509
# 73000	10646
# 74000	10798
# 75000	10948
# 76000	11087
# 77000	11219
# 78000	11325
# 79000	11442
# 80000	11541
# 81000	11664
# 82000	11758
# 83000	11852
# 84000	11961
# 85000	12045
# 86000	12147
# 87000	12236
# 88000	12340
# 89000	12442
# 90000	12533
# 91000	12650
# 92000	12756
# 93000	12854
# 94000	12953
# 95000	13040
# 96000	13133
# 97000	13214
# 98000	13287
# 99000	13372
# 100000	13485
# 101000	13586
# 102000	13717
# 103000	13817
# 104000	13913
# 105000	14021
# 106000	14123
# 107000	14230
# 108000	14324
# 109000	14423
# 110000	14496
# 111000	14581
# 112000	14663
# 113000	14723
# 114000	14794
# 115000	14892
# 116000	14994
# 117000	15097
# 118000	15204
# 119000	15311
# 120000	15409
# 121000	15515
# 122000	15632
# 123000	15756
# 124000	15861
# 125000	15969
# 126000	16100
# 127000	16217
# 128000	16326
# 128872	16426
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.names
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.fasta

# %%
mothur = mothur.count.seqs(name='stability.trim.contigs.good.names', group='stability.contigs.good.groups')
# Out:
# mothur > count.seqs(name=stability.trim.contigs.good.names,group=stability.contigs.good.groups)
#
# Using 1 processors.
# It took 0 secs to create a table for 128872 sequences.
#
#
# Total number of sequences: 128872
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.count_table

# %%
mothur = mothur.summary.seqs(count='stability.trim.contigs.good.count_table')
# Out:
# mothur > summary.seqs(count=stability.trim.contigs.good.count_table)
# Using C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.fasta as input file for the fasta parameter.
#
# Using 1 processors.
#
# 		Start	End	NBases	Ambigs	Polymer	NumSeqs
# Minimum:	1	250	250	0	3	1
# 2.5%-tile:	1	252	252	0	3	3222
# 25%-tile:	1	252	252	0	4	32219
# Median: 	1	252	252	0	4	64437
# 75%-tile:	1	253	253	0	5	96655
# 97.5%-tile:	1	253	253	0	6	125651
# Maximum:	1	270	270	0	12	128872
# Mean:	1	252.462	252.462	0	4.36693
# # of unique seqs:	16426
# total # of seqs:	128872
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.summary
#
# It took 1 secs to summarize 128872 sequences.

# %%
mothur = mothur.pcr.seqs(fasta='silva.bacteria\\silva.bacteria.fasta', start=11894, end=25319, keepdots='F', processors=4)
# Out:
# mothur > pcr.seqs(fasta=silva.bacteria\silva.bacteria.fasta,start=11894,end=25319,keepdots=F,processors=4)
#
# Using 4 processors.
# Processing sequence: 100
# Processing sequence: 100
# Processing sequence: 100
# Processing sequence: 100
# Processing sequence: 200
# Processing sequence: 200
# Processing sequence: 200
# Processing sequence: 200
# Processing sequence: 300
# Processing sequence: 300
# Processing sequence: 300
# Processing sequence: 300
# Processing sequence: 400
# Processing sequence: 400
# Processing sequence: 400
# Processing sequence: 400
# Processing sequence: 500
# Processing sequence: 500
# Processing sequence: 500
# Processing sequence: 500
# Processing sequence: 600
# Processing sequence: 600
# Processing sequence: 600
# Processing sequence: 600
# Processing sequence: 700
# Processing sequence: 700
# Processing sequence: 700
# Processing sequence: 700
# Processing sequence: 800
# Processing sequence: 800
# Processing sequence: 800
# Processing sequence: 800
# Processing sequence: 900
# Processing sequence: 900
# Processing sequence: 900
# Processing sequence: 900
# Processing sequence: 1000
# Processing sequence: 1000
# Processing sequence: 1000
# Processing sequence: 1000
# Processing sequence: 1100
# Processing sequence: 1100
# Processing sequence: 1100
# Processing sequence: 1100
# Processing sequence: 1200
# Processing sequence: 1200
# Processing sequence: 1200
# Processing sequence: 1200
# Processing sequence: 1300
# Processing sequence: 1300
# Processing sequence: 1300
# Processing sequence: 1300
# Processing sequence: 1400
# Processing sequence: 1400
# Processing sequence: 1400
# Processing sequence: 1400
# Processing sequence: 1500
# Processing sequence: 1500
# Processing sequence: 1500
# Processing sequence: 1500
# Processing sequence: 1600
# Processing sequence: 1600
# Processing sequence: 1600
# Processing sequence: 1600
# Processing sequence: 1700
# Processing sequence: 1700
# Processing sequence: 1700
# Processing sequence: 1700
# Processing sequence: 1800
# Processing sequence: 1800
# Processing sequence: 1800
# Processing sequence: 1800
# Processing sequence: 1900
# Processing sequence: 1900
# Processing sequence: 1900
# Processing sequence: 1900
# Processing sequence: 2000
# Processing sequence: 2000
# Processing sequence: 2000
# Processing sequence: 2000
# Processing sequence: 2100
# Processing sequence: 2100
# Processing sequence: 2100
# Processing sequence: 2100
# Processing sequence: 2200
# Processing sequence: 2200
# Processing sequence: 2200
# Processing sequence: 2200
# Processing sequence: 2300
# Processing sequence: 2300
# Processing sequence: 2300
# Processing sequence: 2300
# Processing sequence: 2400
# Processing sequence: 2400
# Processing sequence: 2400
# Processing sequence: 2400
# Processing sequence: 2500
# Processing sequence: 2500
# Processing sequence: 2500
# Processing sequence: 2500
# Processing sequence: 2600
# Processing sequence: 2600
# Processing sequence: 2600
# Processing sequence: 2600
# Processing sequence: 2700
# Processing sequence: 2700
# Processing sequence: 2700
# Processing sequence: 2700
# Processing sequence: 2800
# Processing sequence: 2800
# Processing sequence: 2800
# Processing sequence: 2800
# Processing sequence: 2900
# Processing sequence: 2900
# Processing sequence: 2900
# Processing sequence: 2900
# Processing sequence: 3000
# Processing sequence: 3000
# Processing sequence: 3000
# Processing sequence: 3000
# Processing sequence: 3100
# Processing sequence: 3100
# Processing sequence: 3100
# Processing sequence: 3100
# Processing sequence: 3200
# Processing sequence: 3200
# Processing sequence: 3200
# Processing sequence: 3200
# Processing sequence: 3300
# Processing sequence: 3300
# Processing sequence: 3300
# Processing sequence: 3300
# Processing sequence: 3400
# Processing sequence: 3400
# Processing sequence: 3400
# Processing sequence: 3400
# Processing sequence: 3500
# Processing sequence: 3500
# Processing sequence: 3500
# Processing sequence: 3500
# Processing sequence: 3600
# Processing sequence: 3600
# Processing sequence: 3600
# Processing sequence: 3600
# Processing sequence: 3700
# Processing sequence: 3700
# Processing sequence: 3700
# Thread Processing sequence: 3739
# Processing sequence: 3700
# Thread Processing sequence: 3739
# Thread Processing sequence: 3739
# Processing sequence: 3739
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\silva.bacteria.pcr.fasta
#
#
# It took 10 secs to screen 14956 sequences.

# %%
mothur = mothur.rename.file(input='silva.bacteria.pcr.fasta', new='silva.v4.fasta')
# Out:
# mothur > rename.file(input=silva.bacteria.pcr.fasta,new=silva.v4.fasta)
#
# Current files saved by mothur:
# fasta=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\silva.bacteria.pcr.fasta
# group=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.contigs.good.groups
# name=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.names
# qfile=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.qual
# contigsreport=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.contigs.report
# count=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.count_table
# processors=4
# summary=C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.summary

# %%
mothur = mothur.summary.seqs(fasta='silva.v4.fasta')
# Out:
# mothur > summary.seqs(fasta=silva.v4.fasta)
#
# Using 4 processors.
#
# 		Start	End	NBases	Ambigs	Polymer	NumSeqs
# Minimum:	1	13424	270	0	3	1
# 2.5%-tile:	1	13425	292	0	4	374
# 25%-tile:	1	13425	293	0	4	3740
# Median: 	1	13425	293	0	4	7479
# 75%-tile:	1	13425	293	0	5	11218
# 97.5%-tile:	1	13425	294	1	6	14583
# Maximum:	3	13425	351	5	9	14956
# Mean:	1.00074	13425	292.977	0.0573014	4.57014
# # of Seqs:	14956
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\silva.v4.summary
#
# It took 3 secs to summarize 14956 sequences.

# %%
mothur = mothur.align.seqs(fasta='stability.trim.contigs.good.unique.fasta', reference='silva.v4.fasta')
# Out:
# mothur > align.seqs(fasta=stability.trim.contigs.good.unique.fasta,reference=silva.v4.fasta)
#
# Using 4 processors.
#
# Reading in the C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\silva.v4.fasta template sequences...	DONE.
# It took 4 to read  14956 sequences.
# Aligning sequences from C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.fasta ...
#
# Reading in the C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\silva.v4.fasta template sequences...
# Reading in the C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\silva.v4.fasta template sequences...
# Reading in the C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\silva.v4.fasta template sequences...	100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# DONE.
# It took 4 to read  14956 sequences.
# DONE.
# It took 4 to read  14956 sequences.
# DONE.
# It took 4 to read  14956 sequences.
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 100
# 100
# 100
# 4000
# 200
# 200
# 4100
# 200
# 4108
# 300
# 300
# 300
# 400
# 400
# 400
# 500
# 500
# 500
# 600
# 600
# 600
# 700
# 700
# 700
# 800
# 800
# 800
# 900
# 900
# 900
# 1000
# 1000
# 1000
# 1100
# 1100
# 1100
# 1200
# 1200
# 1200
# 1300
# 1300
# 1300
# 1400
# 1400
# 1400
# 1500
# 1500
# 1500
# 1600
# 1600
# 1600
# 1700
# 1700
# 1700
# 1800
# 1800
# 1800
# 1900
# 1900
# 1900
# 2000
# 2000
# 2000
# 2100
# 2100
# 2100
# 2200
# 2200
# 2200
# 2300
# 2300
# 2300
# 2400
# 2400
# 2400
# 2500
# 2500
# 2500
# 2600
# 2600
# 2600
# 2700
# 2700
# 2700
# 2800
# 2800
# 2800
# 2900
# 2900
# 2900
# 3000
# 3000
# 3000
# 3100
# 3100
# 3100
# 3200
# 3200
# 3200
# 3300
# 3300
# 3300
# 3400
# 3400
# 3400
# 3500
# 3500
# 3500
# 3600
# 3600
# 3700
# 3600
# 3700
# 3800
# 3700
# 3800
# 3900
# 3800
# 3900
# 4000
# 3900
# 4000
# 4100
# 4106
# 4000
# 4100
# 4106
# 4100
# 4106
# It took 11 secs to align 16426 sequences.
#
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.align
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.align.report

# %%
mothur = mothur.summary.seqs(fasta='stability.trim.contigs.good.unique.align', count='stability.trim.contigs.good.count_table')
# Out:
# mothur > summary.seqs(fasta=stability.trim.contigs.good.unique.align,count=stability.trim.contigs.good.count_table)
#
# Using 4 processors.
#
# 		Start	End	NBases	Ambigs	Polymer	NumSeqs
# Minimum:	1250	10693	250	0	3	1
# 2.5%-tile:	1968	11550	252	0	3	3222
# 25%-tile:	1968	11550	252	0	4	32219
# Median: 	1968	11550	252	0	4	64437
# 75%-tile:	1968	11550	253	0	5	96655
# 97.5%-tile:	1968	11550	253	0	6	125651
# Maximum:	1982	13400	270	0	12	128872
# Mean:	1967.99	11550	252.462	0	4.36693
# # of unique seqs:	16426
# total # of seqs:	128872
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.summary
#
# It took 3 secs to summarize 128872 sequences.

# %%
mothur = mothur.filter.seqs(fasta='stability.trim.contigs.good.unique.align', vertical='T', trump='.')
# Out:
# mothur > filter.seqs(fasta=stability.trim.contigs.good.unique.align,vertical=T,trump=.)
#
# Using 4 processors.
# Creating Filter...
# 0
# 0
# 0
# 0
# 100
# 100
# 100
# 100
# 200
# 200
# 200
# 200
# 300
# 300
# 300
# 300
# 400
# 400
# 400
# 400
# 500
# 500
# 500
# 500
# 600
# 600
# 600
# 600
# 700
# 700
# 700
# 700
# 800
# 800
# 800
# 800
# 900
# 900
# 900
# 900
# 1000
# 1000
# 1000
# 1000
# 1100
# 1100
# 1100
# 1100
# 1200
# 1200
# 1200
# 1200
# 1300
# 1300
# 1300
# 1300
# 1400
# 1400
# 1400
# 1400
# 1500
# 1500
# 1500
# 1500
# 1600
# 1600
# 1600
# 1600
# 1700
# 1700
# 1700
# 1700
# 1800
# 1800
# 1800
# 1800
# 1900
# 1900
# 1900
# 1900
# 2000
# 2000
# 2000
# 2000
# 2100
# 2100
# 2100
# 2100
# 2200
# 2200
# 2200
# 2200
# 2300
# 2300
# 2300
# 2300
# 2400
# 2400
# 2400
# 2400
# 2500
# 2500
# 2500
# 2500
# 2600
# 2600
# 2600
# 2600
# 2700
# 2700
# 2700
# 2800
# 2700
# 2800
# 2800
# 2800
# 2900
# 2900
# 2900
# 2900
# 3000
# 3000
# 3000
# 3000
# 3100
# 3100
# 3100
# 3100
# 3200
# 3200
# 3200
# 3200
# 3300
# 3300
# 3300
# 3300
# 3400
# 3400
# 3400
# 3400
# 3500
# 3500
# 3500
# 3500
# 3600
# 3600
# 3600
# 3600
# 3700
# 3700
# 3700
# 3700
# 3800
# 3800
# 3800
# 3800
# 3900
# 3900
# 3900
# 3900
# 4000
# 4000
# 4000
# 4000
# 4100
# 4100
# 4106
# 4106
# 4100
# 4108
# 4100
# 4106
#
#
# Running Filter...
# 0
# 0
# 0
# 100
# 100
# 100
# 100
# 200
# 200
# 200
# 200
# 300
# 300
# 300
# 300
# 400
# 400
# 400
# 400
# 500
# 500
# 500
# 500
# 600
# 600
# 600
# 600
# 700
# 700
# 700
# 700
# 800
# 800
# 800
# 800
# 900
# 900
# 900
# 900
# 1000
# 1000
# 1000
# 1000
# 1100
# 1100
# 1100
# 1100
# 1200
# 1200
# 1200
# 1200
# 1300
# 1300
# 1300
# 1300
# 1400
# 1400
# 1400
# 1400
# 1500
# 1500
# 1500
# 1500
# 1600
# 1600
# 1600
# 1600
# 1700
# 1700
# 1700
# 1700
# 1800
# 1800
# 1800
# 1800
# 1900
# 1900
# 1900
# 1900
# 2000
# 2000
# 2000
# 2000
# 2100
# 2100
# 2100
# 2100
# 2200
# 2200
# 2200
# 2200
# 2300
# 2300
# 2300
# 2300
# 2400
# 2400
# 2400
# 2400
# 2500
# 2500
# 2500
# 2500
# 2600
# 2600
# 2600
# 2600
# 2700
# 2700
# 2700
# 2700
# 2800
# 2800
# 2800
# 2800
# 2900
# 2900
# 2900
# 2900
# 3000
# 3000
# 3000
# 3100
# 3000
# 3100
# 3100
# 3100
# 3200
# 3200
# 3200
# 3200
# 3300
# 3300
# 3300
# 3300
# 3400
# 3400
# 3400
# 3500
# 3400
# 3500
# 3500
# 3600
# 3500
# 3600
# 3600
# 3600
# 3700
# 3700
# 3700
# 3700
# 3800
# 3800
# 3800
# 3800
# 3900
# 3900
# 3900
# 3900
# 4000
# 4000
# 4000
# 4100
# 4000
# 4108
# 4100
# 4100
# 4106
# 4106
# 4100
# 4106
#
#
#
# Length of filtered alignment: 369
# Number of columns removed: 13056
# Length of the original alignment: 13425
# Number of sequences used to construct filter: 16426
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.filter
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.fasta

# %%
mothur = mothur.unique.seqs(fasta='stability.trim.contigs.good.unique.filter.fasta', count='stability.trim.contigs.good.count_table')
# Out:
# mothur > unique.seqs(fasta=stability.trim.contigs.good.unique.filter.fasta,count=stability.trim.contigs.good.count_table)
# 1000	960
# 2000	1913
# 3000	2878
# 4000	3844
# 5000	4804
# 6000	5743
# 7000	6691
# 8000	7647
# 9000	8610
# 10000	9571
# 11000	10514
# 12000	11460
# 13000	12400
# 14000	13357
# 15000	14309
# 16000	15258
# 16426	15647
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.count_table
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.fasta

# %%
mothur = mothur.pre.cluster(fasta='stability.trim.contigs.good.unique.filter.unique.fasta', count='stability.trim.contigs.good.unique.filter.count_table', diffs=2)
# Out:
# mothur > pre.cluster(fasta=stability.trim.contigs.good.unique.filter.unique.fasta,count=stability.trim.contigs.good.unique.filter.count_table,diffs=2)
#
# Using 4 processors.
#
# Processing group F3D0:
#
# Processing group F3D149:
#
# Processing group F3D6:
#
# Processing group F3D144:
# 0	1417	47
# 0	898	37
# 100	500	435
# 0	1272	81
# 200	450	485
# 300	439	496
# 400	434	501
# 500	431	504
# 600	426	509
# 700	419	516
# 800	419	516
# 900	418	517
# 100	626	727
# 200	567	786
# 300	543	810
# 400	538	815
# 500	532	821
# 935	418	517
# Total number of sequences before pre.cluster was 935.
# pre.cluster removed 517 sequences.
#
# 600	519	834
# 700	513	840
# 100	710	754
# 800	509	844
# 900	501	852
# 1000	495	858
# 1100	493	860
# 1200	493	860
# 1300	493	860
# 1353	493	860
# Total number of sequences before pre.cluster was 1353.
# pre.cluster removed 860 sequences.
#
# 0	2123	84
# 200	641	823
# It took 0 secs to cluster 935 sequences.
#
# Processing group F3D145:
# 300	607	857
# 400	598	866
# 100	1091	1116
# 500	587	877
# 600	584	880
# 700	580	884
# 200	963	1244
# 800	572	892
# It took 0 secs to cluster 1353 sequences.
#
# Processing group F3D7:
# 900	568	896
# 300	913	1294
# 1000	563	901
# 400	885	1322
# 1100	562	902
# 1200	558	906
# 1300	558	906
# 500	871	1336
# 1400	558	906
# 600	862	1345
# 700	860	1347
# 1464	558	906
# Total number of sequences before pre.cluster was 1464.
# pre.cluster removed 906 sequences.
#
# 800	856	1351
# 900	854	1353
# 1000	845	1362
# 1100	842	1365
# 1200	838	1369
# 1300	836	1371
# 1400	832	1375
# 1500	824	1383
# 1600	822	1385
# 1700	819	1388
# 1800	819	1388
# 1900	818	1389
# 2000	817	1390
# 2100	817	1390
# 2200	817	1390
# 2207	817	1390
# Total number of sequences before pre.cluster was 2207.
# pre.cluster removed 1390 sequences.
#
# 0	1254	62
# 0	790	51
# 100	395	446
# 200	365	476
# 300	354	487
# 400	346	495
# 100	641	675
# 500	337	504
# 600	335	506
# 700	330	511
# 800	329	512
# 200	584	732
# 300	558	758
# 400	550	766
# 841	329	512
# Total number of sequences before pre.cluster was 841.
# pre.cluster removed 512 sequences.
#
# 500	541	775
# 600	534	782
# 700	528	788
# 800	523	793
# 900	518	798
# 1000	514	802
# 1100	510	806
# 1200	509	807
# 1300	509	807
# It took 0 secs to cluster 2207 sequences.
#
# Processing group F3D150:
# 1316	509	807
# Total number of sequences before pre.cluster was 1316.
# pre.cluster removed 807 sequences.
#
# It took 0 secs to cluster 1464 sequences.
#
# Processing group F3D1:
# It took 0 secs to cluster 841 sequences.
#
# Processing group F3D8:
# It took 0 secs to cluster 1316 sequences.
#
# Processing group F3D146:
# 0	1179	48
# 0	1103	42
# 0	934	43
# 100	674	553
# 100	499	478
# 200	595	632
# 200	458	519
# 300	441	536
# 300	569	658
# 400	434	543
# 400	559	668
# 0	1074	29
# 500	433	544
# 600	429	548
# 500	559	668
# 700	424	553
# 800	422	555
# 900	420	557
# 600	552	675
# 700	550	677
# 800	544	683
# 900	538	689
# 100	581	564
# 1000	533	694
# 1100	533	694
# 1200	532	695
# 977	420	557
# Total number of sequences before pre.cluster was 977.
# pre.cluster removed 557 sequences.
#
# 100	652	451
# 200	574	529
# 300	557	546
# 1227	532	695
# Total number of sequences before pre.cluster was 1227.
# pre.cluster removed 695 sequences.
#
# 400	546	557
# 200	526	619
# 500	543	560
# 600	540	563
# 700	534	569
# 800	528	575
# 300	499	646
# 900	524	579
# 1000	523	580
# 1100	523	580
# 400	492	653
# 500	489	656
# 600	486	659
# It took 0 secs to cluster 977 sequences.
#
# Processing group F3D9:
# It took 0 secs to cluster 1227 sequences.
# 700	481	664
#
# Processing group F3D2:
# 800	480	665
# 900	477	668
# 1000	476	669
# 1100	475	670
# 1145	475	670
# Total number of sequences before pre.cluster was 1145.
# pre.cluster removed 670 sequences.
#
# 1103	523	580
# Total number of sequences before pre.cluster was 1103.
# pre.cluster removed 580 sequences.
#
# 0	1205	56
# 100	649	612
# 200	572	689
# 300	557	704
# 400	549	712
# 500	537	724
# 600	534	727
# It took 0 secs to cluster 1103 sequences.
#
# Processing group F3D147:
# 700	529	732
# 800	525	736
# 900	523	738
# 1000	521	740
# 1100	521	740
# 1200	520	741
# 1261	519	742
# Total number of sequences before pre.cluster was 1261.
# pre.cluster removed 742 sequences.
#
# It took 0 secs to cluster 1145 sequences.
#
# Processing group F3D141:
# 0	2425	210
# 0	1040	47
# It took 0 secs to cluster 1261 sequences.
#
# Processing group Mock:
# 100	1132	1503
# 0	442	52
# 200	1029	1606
# 100	128	366
# 200	125	369
# 300	121	373
# 400	118	376
# 300	965	1670
# 400	929	1706
# 100	537	550
# 500	901	1734
# 494	117	377
# Total number of sequences before pre.cluster was 494.
# pre.cluster removed 377 sequences.
#
# 600	886	1749
# 700	881	1754
# 200	486	601
# 800	874	1761
# 900	868	1767
# 1000	867	1768
# 300	470	617
# 1100	862	1773
# 1200	853	1782
# 1300	852	1783
# 400	459	628
# 1400	851	1784
# 1500	848	1787
# 1600	846	1789
# 1700	842	1793
# 500	458	629
# 1800	840	1795
# 1900	834	1801
# 2000	831	1804
# 2100	828	1807
# 600	458	629
# 2200	828	1807
# 2300	828	1807
# 700	455	632
# 2400	827	1808
# 2500	827	1808
# 2600	827	1808
# 800	450	637
# 900	447	640
# 1000	446	641
# 0	2613	124
# 2635	827	1808
# Total number of sequences before pre.cluster was 2635.
# pre.cluster removed 1808 sequences.
#
# It took 0 secs to cluster 494 sequences.
# 1087	446	641
# Total number of sequences before pre.cluster was 1087.
# pre.cluster removed 641 sequences.
#
# 100	1288	1449
# 200	1175	1562
# It took 0 secs to cluster 2635 sequences.
#
# Processing group F3D3:
# 300	1091	1646
# 400	1045	1692
# 500	1010	1727
# 600	993	1744
# 700	985	1752
# It took 0 secs to cluster 1087 sequences.
#
# Processing group F3D142:
# 800	975	1762
# 900	967	1770
# 1000	954	1783
# 1100	946	1791
# 1200	937	1800
# 1300	934	1803
# 1400	927	1810
# 0	977	72
# 0	686	22
# 1500	924	1813
# 1600	921	1816
# 1700	917	1820
# 1800	913	1824
# 1900	909	1828
# 2000	907	1830
# 100	481	568
# 2100	902	1835
# 2200	900	1837
# 2300	900	1837
# 2400	900	1837
# 2500	899	1838
# 200	442	607
# 100	387	321
# 2600	898	1839
# 2700	897	1840
# 300	434	615
# 400	427	622
# 500	413	636
# 200	354	354
# 600	406	643
# 2737	897	1840
# Total number of sequences before pre.cluster was 2737.
# pre.cluster removed 1840 sequences.
#
# 700	402	647
# 800	401	648
# 900	401	648
# 1000	401	648
# 300	341	367
# 400	332	376
# 500	325	383
# 600	322	386
# 700	322	386
# 708	322	386
# Total number of sequences before pre.cluster was 708.
# pre.cluster removed 386 sequences.
#
# 1049	401	648
# Total number of sequences before pre.cluster was 1049.
# pre.cluster removed 648 sequences.
#
# It took 0 secs to cluster 2737 sequences.
#
# Processing group F3D148:
# It took 0 secs to cluster 1049 sequences.
#
# Processing group F3D5:
# It took 0 secs to cluster 708 sequences.
#
# Processing group F3D143:
# 0	851	32
# 100	474	409
# 0	699	19
# 200	433	450
# 300	428	455
# 0	1979	108
# 400	425	458
# 500	417	466
# 600	413	470
# 700	408	475
# 800	407	476
# 100	398	320
# 883	407	476
# Total number of sequences before pre.cluster was 883.
# pre.cluster removed 476 sequences.
#
# 200	370	348
# 300	361	357
# 100	989	1098
# 400	351	367
# 500	347	371
# 600	342	376
# 700	340	378
# 200	868	1219
# 718	340	378
# Total number of sequences before pre.cluster was 718.
# pre.cluster removed 378 sequences.
#
# 300	809	1278
# It took 0 secs to cluster 883 sequences.
# 400	787	1300
# 500	773	1314
# 600	761	1326
# 700	751	1336
# 800	748	1339
# 900	738	1349
# 1000	733	1354
# 1100	729	1358
# 1200	726	1361
# 1300	724	1363
# 1400	721	1366
# 1500	717	1370
# 1600	715	1372
# 1700	714	1373
# 1800	714	1373
# 1900	713	1374
# 2000	712	1375
# 2087	712	1375
# Total number of sequences before pre.cluster was 2087.
# pre.cluster removed 1375 sequences.
#
# It took 0 secs to cluster 718 sequences.
# It took 0 secs to cluster 2087 sequences.
# It took 1 secs to run pre.cluster.
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.fasta
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.count_table
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D0.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D1.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D141.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D142.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D143.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D144.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D145.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D146.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D147.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D148.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D149.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D150.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D2.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D3.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D5.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D6.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D7.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D8.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.F3D9.map
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.Mock.map

# %%
mothur = mothur.chimera.vsearch(fasta='stability.trim.contigs.good.unique.filter.unique.precluster.fasta', count='stability.trim.contigs.good.unique.filter.unique.precluster.count_table', dereplicate='t')
# Out:
# mothur > chimera.vsearch(fasta=stability.trim.contigs.good.unique.filter.unique.precluster.fasta,count=stability.trim.contigs.good.unique.filter.unique.precluster.count_table,dereplicate=t)
#
# Using 4 processors.
# C:\Users\campen\mothur\1.39.5\mothur\mothur\vsearch.exe file does not exist. Checking path...
# Found vsearch in your path, using C:\Users\campen\mothur\1.39.5\mothur\vsearch.exe
# Checking sequences from C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.fasta ...
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 135989 nt in 558 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 261 (46.8%) chimeras, 290 (52.0%) non-chimeras,
# and 7 (1.3%) borderline sequences in 558 unique sequences.
# Taking abundance information into account, this corresponds to
# 414 (6.2%) chimeras, 6217 (93.7%) non-chimeras,
# and 7 (0.1%) borderline sequences in 6638 total sequences.
#
# It took 0 secs to check 558 sequences from group F3D0.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 115802 nt in 475 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 216 (45.5%) chimeras, 254 (53.5%) non-chimeras,
# and 5 (1.1%) borderline sequences in 475 unique sequences.
# Taking abundance information into account, this corresponds to
# 299 (6.0%) chimeras, 4666 (93.9%) non-chimeras,
# and 5 (0.1%) borderline sequences in 4970 total sequences.
#
# It took 1 secs to check 475 sequences from group F3D1.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 108661 nt in 446 seqs, min 240, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 220 (49.3%) chimeras, 223 (50.0%) non-chimeras,
# and 3 (0.7%) borderline sequences in 446 unique sequences.
# Taking abundance information into account, this corresponds to
# 421 (8.3%) chimeras, 4651 (91.6%) non-chimeras,
# and 3 (0.1%) borderline sequences in 5075 total sequences.
#
# It took 0 secs to check 446 sequences from group F3D141.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 78463 nt in 322 seqs, min 243, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 128 (39.8%) chimeras, 191 (59.3%) non-chimeras,
# and 3 (0.9%) borderline sequences in 322 unique sequences.
# Taking abundance information into account, this corresponds to
# 242 (9.1%) chimeras, 2423 (90.7%) non-chimeras,
# and 5 (0.2%) borderline sequences in 2670 total sequences.
#
# It took 0 secs to check 322 sequences from group F3D142.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 82850 nt in 340 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 156 (45.9%) chimeras, 182 (53.5%) non-chimeras,
# and 2 (0.6%) borderline sequences in 340 unique sequences.
# Taking abundance information into account, this corresponds to
# 275 (10.3%) chimeras, 2395 (89.6%) non-chimeras,
# and 2 (0.1%) borderline sequences in 2672 total sequences.
#
# It took 1 secs to check 340 sequences from group F3D143.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 101826 nt in 418 seqs, min 240, max 248, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 174 (41.6%) chimeras, 240 (57.4%) non-chimeras,
# and 4 (1.0%) borderline sequences in 418 unique sequences.
# Taking abundance information into account, this corresponds to
# 429 (11.1%) chimeras, 3441 (88.8%) non-chimeras,
# and 5 (0.1%) borderline sequences in 3875 total sequences.
#
# It took 0 secs to check 418 sequences from group F3D144.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 123975 nt in 509 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 221 (43.4%) chimeras, 285 (56.0%) non-chimeras,
# and 3 (0.6%) borderline sequences in 509 unique sequences.
# Taking abundance information into account, this corresponds to
# 584 (9.6%) chimeras, 5527 (90.4%) non-chimeras,
# and 3 (0.0%) borderline sequences in 6114 total sequences.
#
# It took 0 secs to check 509 sequences from group F3D145.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 127472 nt in 523 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 249 (47.6%) chimeras, 272 (52.0%) non-chimeras,
# and 2 (0.4%) borderline sequences in 523 unique sequences.
# Taking abundance information into account, this corresponds to
# 460 (10.7%) chimeras, 3839 (89.3%) non-chimeras,
# and 2 (0.0%) borderline sequences in 4301 total sequences.
#
# It took 1 secs to check 523 sequences from group F3D146.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 218496 nt in 897 seqs, min 240, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 472 (52.6%) chimeras, 417 (46.5%) non-chimeras,
# and 8 (0.9%) borderline sequences in 897 unique sequences.
# Taking abundance information into account, this corresponds to
# 1688 (11.9%) chimeras, 12473 (88.0%) non-chimeras,
# and 9 (0.1%) borderline sequences in 14170 total sequences.
#
# It took 1 secs to check 897 sequences from group F3D147.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 173455 nt in 712 seqs, min 241, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 365 (51.3%) chimeras, 338 (47.5%) non-chimeras,
# and 9 (1.3%) borderline sequences in 712 unique sequences.
# Taking abundance information into account, this corresponds to
# 1037 (9.9%) chimeras, 9470 (90.0%) non-chimeras,
# and 17 (0.2%) borderline sequences in 10524 total sequences.
#
# It took 0 secs to check 712 sequences from group F3D148.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 199108 nt in 817 seqs, min 240, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 456 (55.8%) chimeras, 356 (43.6%) non-chimeras,
# and 5 (0.6%) borderline sequences in 817 unique sequences.
# Taking abundance information into account, this corresponds to
# 1034 (9.3%) chimeras, 10051 (90.6%) non-chimeras,
# and 6 (0.1%) borderline sequences in 11091 total sequences.
#
# It took 1 secs to check 817 sequences from group F3D149.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 129640 nt in 532 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 267 (50.2%) chimeras, 261 (49.1%) non-chimeras,
# and 4 (0.8%) borderline sequences in 532 unique sequences.
# Taking abundance information into account, this corresponds to
# 475 (10.3%) chimeras, 4123 (89.5%) non-chimeras,
# and 7 (0.2%) borderline sequences in 4605 total sequences.
#
# It took 1 secs to check 532 sequences from group F3D150.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 201544 nt in 827 seqs, min 241, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 452 (54.7%) chimeras, 363 (43.9%) non-chimeras,
# and 12 (1.5%) borderline sequences in 827 unique sequences.
# Taking abundance information into account, this corresponds to
# 1045 (6.2%) chimeras, 15731 (93.7%) non-chimeras,
# and 17 (0.1%) borderline sequences in 16793 total sequences.
#
# It took 0 secs to check 827 sequences from group F3D2.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 97700 nt in 401 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 183 (45.6%) chimeras, 214 (53.4%) non-chimeras,
# and 4 (1.0%) borderline sequences in 401 unique sequences.
# Taking abundance information into account, this corresponds to
# 462 (8.1%) chimeras, 5207 (91.7%) non-chimeras,
# and 9 (0.2%) borderline sequences in 5678 total sequences.
#
# It took 1 secs to check 401 sequences from group F3D3.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 99208 nt in 407 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 173 (42.5%) chimeras, 231 (56.8%) non-chimeras,
# and 3 (0.7%) borderline sequences in 407 unique sequences.
# Taking abundance information into account, this corresponds to
# 237 (6.4%) chimeras, 3476 (93.5%) non-chimeras,
# and 3 (0.1%) borderline sequences in 3716 total sequences.
#
# It took 0 secs to check 407 sequences from group F3D5.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 120137 nt in 493 seqs, min 241, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 227 (46.0%) chimeras, 263 (53.3%) non-chimeras,
# and 3 (0.6%) borderline sequences in 493 unique sequences.
# Taking abundance information into account, this corresponds to
# 405 (5.9%) chimeras, 6430 (94.0%) non-chimeras,
# and 4 (0.1%) borderline sequences in 6839 total sequences.
#
# It took 1 secs to check 493 sequences from group F3D6.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 80171 nt in 329 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 130 (39.5%) chimeras, 198 (60.2%) non-chimeras,
# and 1 (0.3%) borderline sequences in 329 unique sequences.
# Taking abundance information into account, this corresponds to
# 290 (6.6%) chimeras, 4073 (93.3%) non-chimeras,
# and 2 (0.0%) borderline sequences in 4365 total sequences.
#
# It took 0 secs to check 329 sequences from group F3D7.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 102382 nt in 420 seqs, min 241, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 160 (38.1%) chimeras, 254 (60.5%) non-chimeras,
# and 6 (1.4%) borderline sequences in 420 unique sequences.
# Taking abundance information into account, this corresponds to
# 227 (5.0%) chimeras, 4287 (94.8%) non-chimeras,
# and 10 (0.2%) borderline sequences in 4524 total sequences.
#
# It took 0 secs to check 420 sequences from group F3D8.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 126510 nt in 519 seqs, min 242, max 246, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 235 (45.3%) chimeras, 278 (53.6%) non-chimeras,
# and 6 (1.2%) borderline sequences in 519 unique sequences.
# Taking abundance information into account, this corresponds to
# 346 (5.7%) chimeras, 5765 (94.2%) non-chimeras,
# and 8 (0.1%) borderline sequences in 6119 total sequences.
#
# It took 1 secs to check 519 sequences from group F3D9.
# vsearch v2.3.4_win_x86_64, 63.9GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.temp 100%
# 28538 nt in 117 seqs, min 243, max 248, avg 244
# Masking 100%
# Sorting by abundance 100%
# Counting unique k-mers 100%
# Detecting chimeras 100%
# Found 62 (53.0%) chimeras, 55 (47.0%) non-chimeras,
# and 0 (0.0%) borderline sequences in 117 unique sequences.
# Taking abundance information into account, this corresponds to
# 78 (1.9%) chimeras, 4055 (98.1%) non-chimeras,
# and 0 (0.0%) borderline sequences in 4133 total sequences.
#
# It took 0 secs to check 117 sequences from group Mock.
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.count_table
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.chimeras
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.accnos

# %%
mothur = mothur.remove.seqs(fasta='stability.trim.contigs.good.unique.filter.unique.precluster.fasta', accnos='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.accnos')
# Out:
# mothur > remove.seqs(fasta=stability.trim.contigs.good.unique.filter.unique.precluster.fasta,accnos=stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.accnos)
# [WARNING]: This command can take a namefile and you did not provide one. The current namefile is C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.names which seems to match C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.fasta.
# Removed 3350 sequences from your fasta file.
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.fasta
#
#
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Detected 1 [WARNING] messages, please review.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<^>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
mothur = mothur.summary.seqs(fasta='current', count='current')
# Out:
# mothur > summary.seqs(fasta=current,count=current)
# Using C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.count_table as input file for the count parameter.
# Using C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.fasta as input file for the fasta parameter.
#
# Using 4 processors.
#
# 		Start	End	NBases	Ambigs	Polymer	NumSeqs
# Minimum:	1	369	240	0	3	1
# 2.5%-tile:	1	369	243	0	3	2961
# 25%-tile:	1	369	243	0	4	29607
# Median: 	1	369	243	0	4	59213
# 75%-tile:	1	369	244	0	5	88819
# 97.5%-tile:	1	369	244	0	6	115464
# Maximum:	3	369	248	0	7	118424
# Mean:	1.00003	369	243.464	0	4.37488
# # of unique seqs:	2283
# total # of seqs:	118424
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.summary
#
# It took 0 secs to summarize 118424 sequences.

# %%
mothur = mothur.classify.seqs(fasta='stability.trim.contigs.good.unique.filter.unique.precluster.pick.fasta', count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.count_table', reference='trainset9_032012.pds.fasta', taxonomy='trainset9_032012.pds.tax', cutoff=80)
# Out:
# mothur > classify.seqs(fasta=stability.trim.contigs.good.unique.filter.unique.precluster.pick.fasta,count=stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.count_table,reference=trainset9_032012.pds.fasta,taxonomy=trainset9_032012.pds.tax,cutoff=80)
#
# Using 4 processors.
# Generating search database...    DONE.
# It took 4 seconds generate search database.
#
# Reading in the C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\trainset9_032012.pds.tax taxonomy...	DONE.
# Calculating template taxonomy tree...     DONE.
# Calculating template probabilities...     DONE.
# It took 15 seconds get probabilities.
# Classifying sequences from C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.fasta ...
# Reading template taxonomy...     Reading template taxonomy...     Reading template taxonomy...     DONE.
# Reading template probabilities...     DONE.
# DONE.
# Reading template probabilities...     Reading template probabilities...     Processing sequence: 100
# Processing sequence: 200
# Processing sequence: 300
# Processing sequence: 400
# Processing sequence: 500
# Processing sequence: 573
# DONE.
# It took 24 seconds get probabilities.
# DONE.
# It took 24 seconds get probabilities.
# DONE.
# It took 25 seconds get probabilities.
# Processing sequence: 100
# Processing sequence: 100
# Processing sequence: 100
# Processing sequence: 200
# Processing sequence: 200
# Processing sequence: 200
# Processing sequence: 300
# Processing sequence: 300
# Processing sequence: 300
# Processing sequence: 400
# Processing sequence: 400
# Processing sequence: 400
# Processing sequence: 500
# Processing sequence: 500
# Processing sequence: 500
# Processing sequence: 570
# Processing sequence: 570
# Processing sequence: 570
#
# It took 28 secs to classify 2283 sequences.
#
#
# It took 0 secs to create the summary file for 2283 sequences.
#
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.taxonomy
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.tax.summary

# %%
mothur = mothur.remove.lineage(fasta='stability.trim.contigs.good.unique.filter.unique.precluster.pick.fasta', count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.count_table', taxonomy='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.taxonomy', taxon='Chloroplast-Mitochondria-unknown-Archaea-Eukaryota')
# Out:
# mothur > remove.lineage(fasta=stability.trim.contigs.good.unique.filter.unique.precluster.pick.fasta,count=stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.count_table,taxonomy=stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.taxonomy,taxon=Chloroplast-Mitochondria-unknown-Archaea-Eukaryota)
#
# [NOTE]: The count file should contain only unique names, so mothur assumes your fasta, list and taxonomy files also contain only uniques.
#
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.pick.taxonomy
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.fasta
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.count_table

# %%
mothur = mothur.summary.tax(taxonomy='current', count='current')
# Out:
# mothur > summary.tax(taxonomy=current,count=current)
# Using C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.count_table as input file for the count parameter.
# Using C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.pick.taxonomy as input file for the taxonomy parameter.
#
# It took 0 secs to create the summary file for 118254 sequences.
#
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.pick.tax.summary

# %%
# mothur = mothur.get.groups(count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.count_table', fasta='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.fasta', groups='Mock')

# %%
# mothur = mothur.seq.error(fasta='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.fasta', count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table', reference='MiSeq_SOP\HMP_MOCK.v35.fasta', aligned='F')

# %%
# mothur = mothur.dist.seqs(fasta='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.fasta', cutoff=0.03)
# mothur = mothur.cluster(column='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.dist', count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table')
# mothur = mothur.make.shared(list='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.list', count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table', label=0.03)
# mothur = mothur.rarefaction.single(shared='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.shared')

# %%
mothur = mothur.remove.groups(count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.count_table', fasta='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.fasta', taxonomy='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.pick.taxonomy', groups='Mock')
# Out:
# mothur > remove.groups(count=stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.count_table,fasta=stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.fasta,taxonomy=stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.pick.taxonomy,groups=Mock)
#
# [NOTE]: The count file should contain only unique names, so mothur assumes your fasta, list and taxonomy files also contain only uniques.
#
# Removed 32 sequences from your fasta file.
# Removed 4055 sequences from your count file.
# Removed 32 sequences from your taxonomy file.
#
# Output File names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.fasta
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.pick.pick.taxonomy

# %%
mothur = mothur.dist.seqs(fasta='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.fasta', cutoff=0.03)
mothur = mothur.cluster(column='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.dist', count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table')
# Out:
# mothur > dist.seqs(fasta=stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.fasta,cutoff=0.03)
#
# Using 4 processors.
# 0	0
# 100	0
# 200	0
# 1600	1
# 300	1
# 400	1
# 1200	1
# 2000	1
# 500	1
# 600	1
# 1700	1
# 1300	1
# 700	1
# 2100	1
# 800	1
# 1400	1
# 1800	1
# 900	1
# 1500	1
# 1000	1
# 1900	1
# 2200	1
# 1100	2
# 354	2
# 299	2
# 1113	2
# 462	2
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.dist
#
# It took 2 seconds to calculate the distances for 2229 sequences.
#
# mothur > cluster(column=stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.dist,count=stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table)
#
# Using 4 processors.
#
# You did not set a cutoff, using 0.03.
#
# Clustering C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.dist
#
#
# iter	time	label	num_otus	cutoff	tp	tn	fp	fn	sensitivity	specificity	ppv	npv	fdr	accuracy	mcc	f1score
# 0	0	0.03	2229	0.03	0	2463014	0	20092	0	1	0	0.991909	0	0.991909	0	0
# 1	0	0.03	526	0.03	16813	2461389	1625	3279	0.836801	0.99934	0.911867	0.99867	0.0881332	0.998025	0.872546	0.872723
# 2	0	0.03	490	0.03	17193	2461360	1654	2899	0.855714	0.999328	0.912241	0.998824	0.0877593	0.998166	0.882609	0.883074
# 3	0	0.03	487	0.03	17208	2461349	1665	2884	0.85646	0.999324	0.911779	0.99883	0.0882213	0.998168	0.882771	0.883254
# 4	0	0.03	488	0.03	17204	2461354	1660	2888	0.856261	0.999326	0.912002	0.998828	0.0879983	0.998168	0.882776	0.883253
#
#
# It took 0 seconds to cluster
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.list
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.steps
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.sensspec

# %%
mothur = mothur.make.shared(list='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.list', count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table', label=0.03)
# Out:
# mothur > make.shared(list=stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.list,count=stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table,label=0.03)
# 0.03
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.shared

# %%
mothur = mothur.classify.otu(list='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.list', count='stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table', taxonomy='stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.pick.pick.taxonomy', label=0.03)
# Out:
# mothur > classify.otu(list=stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.list,count=stability.trim.contigs.good.unique.filter.unique.precluster.denovo.vsearch.pick.pick.pick.count_table,taxonomy=stability.trim.contigs.good.unique.filter.unique.precluster.pick.pds.wang.pick.pick.taxonomy,label=0.03)
# 0.03	488
#
# Output File Names:
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.0.03.cons.taxonomy
# C:\Users\campen\Documents\coding\python\rhea\example\Mothur_MiSeq_SOP\stability.trim.contigs.good.unique.filter.unique.precluster.pick.pick.pick.opti_mcc.0.03.cons.tax.summary

# %%
from pprint import pprint
mothur
# Out:
# 'rhea.Mothur'
